# %%
from utils import config_logging, configure_kafka_producer, intialise_spark_session
from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StructType, StructField, StringType, FloatType
import requests
import logging
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from utils import config_logging, configure_kafka_producer, intialise_spark_session
#       2 from pyspark.sql.functions import from_json, col
#       3 from pyspark.sql.types import StructType, StructField, StringType, FloatType
#
# ModuleNotFoundError: No module named 'utils'

# %%
logging = config_logging()
spark = intialise_spark_session()

# %%
def extract_bike_networks(producer: str, topic: str) -> None:

    url = "http://api.citybik.es/v2/networks"

    try:
        
        response = requests.get(url)

        if response.status_code == 200:
            logging.info("Data fetched successfully.")
            data = response.json()
            
            for network in data["networks"]:
                if network["location"]["country"] in ["US", "GB", "CA", "AU"]:

                    network_location = network.get("location", {})

                    streaming_data =  {
                    "id": network.get("id"),
                    "name": network.get("name"),
                    "latitude": network_location.get("latitude"),
                    "longitude": network_location.get("longitude"),
                    "city": network_location.get("city"),
                    "country": network_location.get("country"),
                    "company": network.get("company")[0]

                    }
                
                    producer.send(topic, value=json.dumps(streaming_data).encode('utf-8'))
                    producer.flush()
                    
                    logging.info(f"Streaming data sent to Kafka topic {topic}")

    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching data: {e}")
        return None

# %%
def transform_schema():
    bike_networks = StructType([
        StructField("id", StringType(), True),
        StructField("name", StringType(), True),
        StructField("latitude", FloatType(), True),
        StructField("longitude", FloatType(), True),
        StructField("city", StringType(), True),
        StructField("country", StringType(), True),
        StructField("company", StringType(), True),
    ])

    return bike_networks

# %%
def consume_data(bootstrap_servers, topic):
    try:
        df = spark.readStream.format("kafka") \
            .option("kafka.bootstrap.servers", bootstrap_servers) \
            .option("subscribe", topic) \
            .option("delimiter", ",")\
            .load()
        logging.info("Data consumed successfully.")

        transformed_df = df.selectExpr("CAST(value AS STRING)")\
        .select(from_json(col("value", transform_schema)\
        .alias("data")))\
        .select("data.*")

        return transformed_df

    except Exception as e:
        logging.error(f"Error consuming data: {e}")
        return None

# %%
def main():
    try:
        spark = intialise_spark_session()
        bootstrap_servers = "bootstrap_servers"
        producer  = configure_kafka_producer(bootstrap_servers)
        topic = "list_of_bike_networks"

        if not spark or bootstrap_servers or producer or topic:
            logging.error("Missing variable configuration: check your configuration.")
            return

        extract_bike_networks(producer, topic)
        transformed_df = consume_data(bootstrap_servers, topic)

    except Exception as e:
        logging.error(f"An error occurred: {e}")
    finally:
        producer.close()
        spark.stop()
        
        logging.info("Spark session stopped.")

# %%
if __name__ == "__main__":
    main()

# %%
import requests
url = f"http://api.citybik.es/v2/networks"


response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    
    all_networks = []
    all_ids = []
    for network in data["networks"]:
        if network["location"]["country"] in ["US", "GB", "CA"]:

            network_location = network.get("location", {})

            streaming_data =  {
            "id": network.get("id"),
            "name": network.get("name"),
            "latitude": network_location.get("latitude"),
            "longitude": network_location.get("longitude"),
            "city": network_location.get("city"),
            "country": network_location.get("country"),
            "company": network.get("company")
            }
            all_ids.append(network.get("id"))
            all_networks.append(streaming_data)

# %%
all_ids = [ids["id"] for ids in all_networks]

# %%
all_ids
# Out:
# ['acces-velo-saguenay',
#  'avelo-quebec',
#  'aventura',
#  'bay-wheels',
#  'belfastbikes-belfast',
#  'bentonville',
#  'beryl-bcp',
#  'beryl-brighton',
#  'beryl-cornwall',
#  'beryl-dorchester-weymouth-portland',
#  'beryl-eastleigh',
#  'beryl-greater-manchester',
#  'beryl-guildford',
#  'beryl-hereford',
#  'beryl-hertsmere',
#  'beryl-leeds',
#  'beryl-norwich',
#  'beryl-plymouth',
#  'beryl-stevenage',
#  'beryl-watford',
#  'beryl-west-midlands',
#  'beryl-worcester',
#  'bike-chattanooga',
#  'biketown',
#  'biketown-whq',
#  'bismarck',
#  'bixi-montreal',
#  'bixi-toronto',
#  'blue-bikes',
#  'boulder',
#  'broward',
#  'bublr-bikes',
#  'capital-bikeshare',
#  'capmetro-austin',
#  'charlotte',
#  'cincy-red-bike',
#  'citi-bike-miami',
#  'citi-bike-nyc',
#  'clemson',
#  'co-bikes-exeter',
#  'cogo',
#  'denver',
#  'desmoines',
#  'divvy',
#  'elpaso',
#  'fortworth',
#  'gobiki',
#  'greenbikeslc',
#  'greenville',
#  'hi-bike-fort-william',
#  'hi-bike-inverness',
#  'hibike',
#  'indego',
#  'indiana-pacers-bikeshare',
#  'jackson',
#  'joco-new-york',
#  'lincoln',
#  'madison',
#  'mcallen',
#  'memphis',
#  'metro-bike-share',
#  'mobibikes',
#  'mogo-detroit',
#  'nashville',
#  'nextbike-cardiff',
#  'nextbike-glasgow',
#  'nextbike-stirling',
#  'nextbike-university-of-surrey',
#  'omaha',
#  'peacehealth-rides',
#  'pittsburgh',
#  'redding',
#  'reddy-bike-share',
#  'relay-atlanta',
#  'rtc-bike-share',
#  'rva-bikes',
#  'sanantonio',
#  'santa-barbara',
#  'santa-cruz',
#  'santander-brunel',
#  'santander-cycles',
#  'santander-cycles-mk-milton-keynes',
#  'santander-cycles-swansea-swansea-university',
#  'sobi-hamilton',
#  'sobi-long-beach',
#  'summit-bike-share',
#  'tugo-bike-share',
#  'valentine',
#  'we-cycle',
#  'westcargo-bath',
#  'westcargo-bristol',
#  'wolf-ride-bike-share']

# %%
all_idss = ['acces-velo-saguenay',
 'avelo-quebec',
 'aventura',
 'bay-wheels',
 'belfastbikes-belfast']

# %%
import aiohttp
import asyncio
import json


async def fetch(url):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            if response.status == 200:
                data = await response.text()
                return data


    
tasks = []

urls = [f"http://api.citybik.es/v2/networks/{network_id}" for network_id in all_idss]

for url in urls:
    tasks.append(fetch(url))    
    print(tasks)

responses = await asyncio.gather(*tasks)

# get_ids = []
all_stations = []
for response in responses:
    if response:
        response = json.loads(response)
        # get_ids.append(response.get("network", {}).get("id"))

        tasks_stations = response.get("network", {}).get("stations", [])
        

        for stations in tasks_stations:
            streaming_data = ({
                "id": response.get("network", {}).get("id"),
                "station_id": stations["id"],
                "name": stations["name"],
                "latitude": stations["latitude"],
                "longitude": stations["longitude"],
                "timestamp": stations["timestamp"],
                "free_bikes": stations["free_bikes"],
                "empty_slots": stations["empty_slots"],
                "uid": stations["extra"].get("uid", None),
                "renting": stations["extra"].get("renting", 0),
                "returning": stations["extra"].get("returning", 0),
                "last_updated": stations["extra"].get("last_updated", 0),
                "address": stations["extra"].get("address", None),
                "has_ebikes": stations["extra"].get("has_ebikes", 0),
                "ebikes": stations["extra"].get("ebikes", 0),
                "normal_bikes": stations["extra"].get("normal_bikes", 0)
            })

            all_stations.append(streaming_data)
# Out:
# [<coroutine object fetch at 0x7fef64c6dee0>]
# [<coroutine object fetch at 0x7fef64c6dee0>, <coroutine object fetch at 0x7fef64cf8c10>]
# [<coroutine object fetch at 0x7fef64c6dee0>, <coroutine object fetch at 0x7fef64cf8c10>, <coroutine object fetch at 0x7fef64cf94d0>]
# [<coroutine object fetch at 0x7fef64c6dee0>, <coroutine object fetch at 0x7fef64cf8c10>, <coroutine object fetch at 0x7fef64cf94d0>, <coroutine object fetch at 0x7fef64cf9540>]
# [<coroutine object fetch at 0x7fef64c6dee0>, <coroutine object fetch at 0x7fef64cf8c10>, <coroutine object fetch at 0x7fef64cf94d0>, <coroutine object fetch at 0x7fef64cf9540>, <coroutine object fetch at 0x7fef64cf93f0>]

# %%
import json

# Open a file in write mode and save the JSON data
with open("sample_networks.json", "w") as json_file:
    json.dump(all_networks, json_file, indent=2)  # indent is optional, it formats the output to be more readable

# %%
import aiohttp
import asyncio
import json


async def fetch(url):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            if response.status == 200:
                data = await response.text()
                return data


async def fetch_all_stations(url):  
    
    url = "http://api.citybik.es/v2/networks"
    urls = [f"{url}/{network_id}" for network_id in all_idss]

    tasks = []
    for url in urls:
        tasks.append(fetch(url))    
        

    responses = await asyncio.gather(*tasks)

    all_stations = []


    for response in responses:
        if response:
            response = json.loads(response)

            tasks_stations = response.get("network", {}).get("stations", [])
        

        for stations in tasks_stations:
            streaming_data = ({
                "id": response.get("network", {}).get("id"),
                "station_id": stations["id"],
                "name": stations["name"],
                "latitude": stations["latitude"],
                "longitude": stations["longitude"],
                "timestamp": stations["timestamp"],
                "free_bikes": stations["free_bikes"],
                "empty_slots": stations["empty_slots"],
                "uid": stations["extra"].get("uid", None),
                "renting": stations["extra"].get("renting", 0),
                "returning": stations["extra"].get("returning", 0),
                "last_updated": stations["extra"].get("last_updated", 0),
                "address": stations["extra"].get("address", None),
                "has_ebikes": stations["extra"].get("has_ebikes", 0),
                "ebikes": stations["extra"].get("ebikes", 0),
                "normal_bikes": stations["extra"].get("normal_bikes", 0)
            })

            all_stations.append(streaming_data)

    return all_stations
            
async def main():
    all_stations = await fetch_all_stations("http://api.citybik.es/v2/networks")
    return all_stations

all_stations = await main()

# %%
import aiohttp
import asyncio
import json
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StructType, StructField, StringType, FloatType


spark = SparkSession.builder \
    .appName("BikeNetworkStreaming") \
    .getOrCreate()

async def fetch(url):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            if response.status == 200:
                data = await response.text()
                return data


async def fetch_all_stations(url):  
    
    url = "http://api.citybik.es/v2/networks"
    urls = [f"{url}/{network_id}" for network_id in all_idss]

    tasks = []
    for url in urls:
        tasks.append(fetch(url))    
        

    responses = await asyncio.gather(*tasks)

    all_stations = []


    for response in responses:
        if response:
            response = json.loads(response)

            tasks_stations = response.get("network", {}).get("stations", [])
        

        for stations in tasks_stations:
            streaming_data = ({
                "id": response.get("network", {}).get("id"),
                "station_id": stations["id"],
                "name": stations["name"],
                "latitude": stations["latitude"],
                "longitude": stations["longitude"],
                "timestamp": stations["timestamp"],
                "free_bikes": stations["free_bikes"],
                "empty_slots": stations["empty_slots"],
                "uid": stations["extra"].get("uid", None),
                "renting": stations["extra"].get("renting", 0),
                "returning": stations["extra"].get("returning", 0),
                "last_updated": stations["extra"].get("last_updated", 0),
                "address": stations["extra"].get("address", None),
                "has_ebikes": stations["extra"].get("has_ebikes", 0),
                "ebikes": stations["extra"].get("ebikes", 0),
                "normal_bikes": stations["extra"].get("normal_bikes", 0)
            })

            all_stations.append(streaming_data)

    return all_stations
            
async def main():
    all_stations = await fetch_all_stations("http://api.citybik.es/v2/networks")
    return all_stations

all_stations = await main()
# Out:
# your 131072x1 screen size is bogus. expect trouble
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/15 19:11:28 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
all_stations
# Out:
# [{'id': 'acces-velo-saguenay',
#   'station_id': '0b1c0c48e94fae24b1a38f4559a5985a',
#   'name': 'UQAC',
#   'latitude': 48.42048,
#   'longitude': -71.05338,
#   'timestamp': '2025-04-15T18:09:42.393509Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '2',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1730118608,
#   'address': 'UQAC',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': '138fa8c4b31f783bd4af0afb3151df37',
#   'name': 'Terminus Ste-Therese',
#   'latitude': 48.4326802,
#   'longitude': -71.175537,
#   'timestamp': '2025-04-15T18:09:42.393721Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '17',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744740550,
#   'address': 'Treminus Ste-Therese',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': '3aa299f4d3048ef94737bbf5fbc03825',
#   'name': 'Place du Royaume',
#   'latitude': 48.4044567,
#   'longitude': -71.0582083,
#   'timestamp': '2025-04-15T18:09:42.393527Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '3',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1730116444,
#   'address': 'Place du Royaume',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': '69d867d07bfa8e717eb7b711b664d4b8',
#   'name': 'Centre-Ville Kenogami',
#   'latitude': 48.4241013,
#   'longitude': -71.2393211,
#   'timestamp': '2025-04-15T18:09:42.393662Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '13',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1730138819,
#   'address': 'Centre-Ville',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': '7ada5d893c40c9a46a54f771a392db6f',
#   'name': 'Cégep de Chicoutimi',
#   'latitude': 48.42511890000001,
#   'longitude': -71.0513359,
#   'timestamp': '2025-04-15T18:09:42.393543Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '4',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744740497,
#   'address': 'Cégep de Chicoutimi',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': '989fc50e15bad6b1f40d26f986d50ccc',
#   'name': 'Station Rene-Levesque',
#   'latitude': 48.404255,
#   'longitude': -71.2163722,
#   'timestamp': '2025-04-15T18:09:42.393632Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '9',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744740488,
#   'address': None,
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': 'a114feb6f734b697dd617e2ed795556d',
#   'name': 'Carre Davis',
#   'latitude': 48.4260924,
#   'longitude': -71.1820973,
#   'timestamp': '2025-04-15T18:09:42.393574Z',
#   'free_bikes': 1,
#   'empty_slots': 8,
#   'uid': '7',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1730140122,
#   'address': 'Test-Montreal',
#   'has_ebikes': True,
#   'ebikes': 1,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': 'b6903d788830595e054121e462598381',
#   'name': 'Place du Citoyen',
#   'latitude': 48.4280227,
#   'longitude': -71.0625061,
#   'timestamp': '2025-04-15T18:09:42.393484Z',
#   'free_bikes': 0,
#   'empty_slots': 4,
#   'uid': '1',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744683241,
#   'address': 'Place du Citoyen',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': 'c3cbb301cd817d6cbffdc97636f3d405',
#   'name': 'Parc Riviere-du-moulin',
#   'latitude': 48.3989743,
#   'longitude': -71.0467171,
#   'timestamp': '2025-04-15T18:09:42.393692Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '15',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744740494,
#   'address': 'Parc Riviere-du-moulin',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': 'e5b2a5bf7b36bcd5d52ca0d63a56ae06',
#   'name': 'Terminus Jonquiere',
#   'latitude': 48.4118069,
#   'longitude': -71.2548896,
#   'timestamp': '2025-04-15T18:09:42.393648Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '10',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744740539,
#   'address': None,
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': 'f450af93c8d0f5ae5de8ea7cb1aafe70',
#   'name': 'Terminus La Baie',
#   'latitude': 48.3372301,
#   'longitude': -70.8795642,
#   'timestamp': '2025-04-15T18:09:42.393558Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '5',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744740535,
#   'address': None,
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': 'f4c06361a55bdcba4b8987ed2baca222',
#   'name': 'Quai des croisieres',
#   'latitude': 48.3438044,
#   'longitude': -70.880053,
#   'timestamp': '2025-04-15T18:09:42.393677Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '14',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744740412,
#   'address': 'Quai des croisieres',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': 'fea57cb8975dfedce5badadddd94ee2d',
#   'name': 'Parc du Bassin',
#   'latitude': 48.4255078,
#   'longitude': -71.0740644,
#   'timestamp': '2025-04-15T18:09:42.393707Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '16',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744740388,
#   'address': 'Parc du Bassin',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'acces-velo-saguenay',
#   'station_id': 'ff9bd0107ab0db14c0edc30a03fed1f0',
#   'name': 'Chicoutimi-Nord (rue du Pont)',
#   'latitude': 48.4360499,
#   'longitude': -71.0672709,
#   'timestamp': '2025-04-15T18:09:42.393613Z',
#   'free_bikes': 0,
#   'empty_slots': 7,
#   'uid': '8',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744740527,
#   'address': None,
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'avelo-quebec',
#   'station_id': '519934d003ffebd03c53823e15c1dd80',
#   'name': 'Fleur-de-Lys / Wilfrid-Hamel',
#   'latitude': 46.82027622149531,
#   'longitude': -71.24956383148204,
#   'timestamp': '2025-04-09T19:50:20.302260Z',
#   'free_bikes': 0,
#   'empty_slots': 40,
#   'uid': '133',
#   'renting': True,
#   'returning': True,
#   'last_updated': 1744228082,
#   'address': 'Fleur-de-Lys / Wilfrid-hamel',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'aventura',
#   'station_id': '01d54f0d58e08982715d75e35faa1e0c',
#   'name': 'North Country Club Drive ',
#   'latitude': 25.96605,
#   'longitude': -80.13356,
#   'timestamp': '2025-04-15T18:09:39.201898Z',
#   'free_bikes': 2,
#   'empty_slots': 10,
#   'uid': 'bcycle_aventura_3531',
#   'renting': 1,
#   'returning': 1,
#   'last_updated': 1744740579,
#   'address': 'NE 34th Ave. & Country Club Dr.',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 2},
#  {'id': 'aventura',
#   'station_id': '29ed4cb451bb559fef86c1e08b0dba39',
#   'name': 'Community Recreation Center',
#   'latitude': 25.94985,
#   'longitude': -80.13574,
#   'timestamp': '2025-04-15T18:09:39.201918Z',
#   'free_bikes': 5,
#   'empty_slots': 5,
#   'uid': 'bcycle_aventura_3532',
#   'renting': 1,
#   'returning': 1,
#   'last_updated': 1744740579,
#   'address': '3375 NE 188th St.',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 5},
#  {'id': 'aventura',
#   'station_id': '48050472266c5e77517f35db58a26543',
#   'name': 'Aventura Mall Transit Station',
#   'latitude': 25.9582,
#   'longitude': -80.14436,
#   'timestamp': '2025-04-15T18:09:39.201942Z',
#   'free_bikes': 5,
#   'empty_slots': 7,
#   'uid': 'bcycle_aventura_3535',
#   'renting': 1,
#   'returning': 1,
#   'last_updated': 1744740579,
#   'address': '19501 Biscayne Blvd.',
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes':

#   'address': None,
#   'has_ebikes': True,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'bay-wheels',
#   'station_id': '2367c9313860a8dbae94ac5045768995',
#   'name': 'Berkeley Civic Center',
#   'latitude': 37.8690599,
#   'longitude': -122.270556,
#   'timestamp': '2025-04-15T18:09:41.878811Z',
#   'free_bikes': 21,
#   'empty_slots': 6,
#   'uid': '99665404-d98e-472c-9f68-0016be3601db',
#   'renting': 1,
#   'returning': 1,
#   'last_updated': 1744740515,
#   'address': None,
#   'has_ebikes': True,
#   'ebikes': 9,
#   'normal_bikes': 0},
#  {'id': 'bay-wheels',
#   'station_id': '23c911eba61c38bd79e4df21cf9a8bc6',
#   'name': 'Webster St at Grove St',
#   'latitude': 37.7770527,
#   'longitude': -122.4295585,
#   'timestamp': '2025-04-15T18:09:41.854018Z',
#   'free_bikes': 0,
#   'empty_slots': 26,
# ...
#   'empty_slots': 6,
#   'uid': '20755939',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '63749ff4c0e10b00b94ec6671f02cbf5',
#   'name': 'St Georges Market / Cromac Square',
#   'latitude': 54.595255,
#   'longitude': -5.92368,
#   'timestamp': '2025-04-15T18:09:32.772466Z',
#   'free_bikes': 2,
#   'empty_slots': 8,
#   'uid': '20756545',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '640571b8e3c670c4ae9cdc5e6fe61221',
#   'name': 'Kennedy Centre',
#   'latitude': 54.581962,
#   'longitude': -5.977871,
#   'timestamp': '2025-04-15T18:09:32.772691Z',
#   'free_bikes': 0,
#   'empty_slots': 8,
#   'uid': '141612455',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '656c86839a96158c68bc0ca3edbd782e',
#   'name': 'Cotton Court',
#   'latitude': 54.601425,
#   'longitude': -5.925847,
#   'timestamp': '2025-04-15T18:09:32.771919Z',
#   'free_bikes': 1,
#   'empty_slots': 11,
#   'uid': '20755194',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '66c5fa44bc97bb910261f65625cadc6d',
#   'name': 'Queens University Road',
#   'latitude': 54.583948,
#   'longitude': -5.936989,
#   'timestamp': '2025-04-15T18:09:32.772216Z',
#   'free_bikes': 2,
#   'empty_slots': 15,
#   'uid': '20756347',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '68b7969cfee863bfe67f77f04114a706',
#   'name': 'Waterfront',
#   'latitude': 54.59727,
#   'longitude': -5.921116,
#   'timestamp': '2025-04-15T18:09:32.772539Z',
#   'free_bikes': 3,
#   'empty_slots': 17,
#   'uid': '20756762',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '6bf6e588dec71ba0846a28656aa849f5',
#   'name': 'Falls Road',
#   'latitude': 54.599399,
#   'longitude': -5.947595,
#   'timestamp': '2025-04-15T18:09:32.771976Z',
#   'free_bikes': 1,
#   'empty_slots': 8,
#   'uid': '20755478',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '6cab7b01cc9babc80997df66544f578b',
#   'name': 'Corporation Square',
#   'latitude': 54.604948,
#   'longitude': -5.921534,
#   'timestamp': '2025-04-15T18:09:32.771900Z',
#   'free_bikes': 1,
#   'empty_slots': 12,
#   'uid': '20755087',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '6d83f43a07e68cf858d45d8b7c05e798',
#   'name': 'Queens University / Botanic Gardens',
#   'latitude': 54.583901,
#   'longitude': -5.93281,
#   'timestamp': '2025-04-15T18:09:32.772198Z',
#   'free_bikes': 4,
#   'empty_slots': 8,
#   'uid': '20756307',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '8289d9103cdb90db6334275fc542cb34',
#   'name': 'Linenhall / Donegall Square South',
#   'latitude': 54.59584,
#   'longitude': -5.929881,
#   'timestamp': '2025-04-15T18:09:32.772097Z',
#   'free_bikes': 0,
#   'empty_slots': 16,
#   'uid': '20755957',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '8440a5abef95b3b414405fec0cb6e492',
#   'name': 'Waterworks',
#   'latitude': 54.618475,
#   'longitude': -5.938534,
#   'timestamp': '2025-04-15T18:09:32.772705Z',
#   'free_bikes': 1,
#   'empty_slots': 7,
#   'uid': '151944403',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '8578adf3a35519574fa74f86e46745b7',
#   'name': 'Arthur Street / Chichester Street',
#   'latitude': 54.597573,
#   'longitude': -5.927663,
#   'timestamp': '2025-04-15T18:09:32.772558Z',
#   'free_bikes': 4,
#   'empty_slots': 4,
#   'uid': '20757725',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '8720f7bbbd932e035e71346ec1eeb2d6',
#   'name': 'Grove Well-Being Centre ',
#   'latitude': 54.621307,
#   'longitude': -5.923744,
#   'timestamp': '2025-04-15T18:09:32.772835Z',
#   'free_bikes': 6,
#   'empty_slots': 10,
#   'uid': '391476567',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '91ed9ad1a3a491439998bb1a10ab3f39',
#   'name': 'Falls Road / Coláiste Feirste',
#   'latitude': 54.590889,
#   'longitude': -5.967314,
#   'timestamp': '2025-04-15T18:09:32.772763Z',
#   'free_bikes': 0,
#   'empty_slots': 9,
#   'uid': '282005664',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '9300a6ef8eb89cddfced7aaec8ba83ae',
#   'name': 'Royal Avenue / Castlecourt',
#   'latitude': 54.601319,
#   'longitude': -5.931308,
#   'timestamp': '2025-04-15T18:09:32.772234Z',
#   'free_bikes': 5,
#   'empty_slots': 8,
#   'uid': '20756366',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '971562c0f1b1fb28f74701cf85fd556b',
#   'name': 'Antrim Road / Duncairn Centre',
#   'latitude': 54.612417,
#   'longitude': -5.936748,
#   'timestamp': '2025-04-15T18:09:32.771698Z',
#   'free_bikes': 3,
#   'empty_slots': 5,
#   'uid': '20753518',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': '9799d6da60ffe54487335f37ba48c344',
#   'name': 'AllState',
#   'latitude': 54.594321,
#   'longitude': -5.915236,
#   'timestamp': '2025-04-15T18:09:32.771674Z',
#   'free_bikes': 2,
#   'empty_slots': 11,
#   'uid': '20752458',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'a4b62644b2e7daa727ef8d0e61cea19d',
#   'name': 'Mater Hospital / Crumlin Road',
#   'latitude': 54.608528,
#   'longitude': -5.941029,
#   'timestamp': '2025-04-15T18:09:32.772111Z',
#   'free_bikes': 0,
#   'empty_slots': 10,
#   'uid': '20756015',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'a5c0f5dba8469416690a18cce91ee0b3',
#   'name': 'Skainos',
#   'latitude': 54.598753,
#   'longitude': -5.899396,
#   'timestamp': '2025-04-15T18:09:32.772427Z',
#   'free_bikes': 2,
#   'empty_slots': 6,
#   'uid': '20756473',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'a81148aaa98ce5d0ea14ceecdce18efc',
#   'name': 'Gasworks (Lagan Towpath)',
#   'latitude': 54.591219,
#   'longitude': -5.92265,
#   'timestamp': '2025-04-15T18:09:32.772030Z',
#   'free_bikes': 0,
#   'empty_slots': 15,
#   'uid': '20755678',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'aa67d0efce9be97dd83c03706b61b2e5',
#   'name': 'Ormeau Park',
#   'latitude': 54.580556,
#   'longitude': -5.920504,
#   'timestamp': '2025-04-15T18:09:32.772162Z',
#   'free_bikes': 5,
#   'empty_slots': 5,
#   'uid': '20756194',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'afbcf7d9c0a43c0ab8429d836da6d602',
#   'name': 'Connswater',
#   'latitude': 54.596086,
#   'longitude': -5.892781,
#   'timestamp': '2025-04-15T18:09:32.771880Z',
#   'free_bikes': 12,
#   'empty_slots': 0,
#   'uid': '20754974',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'b0588c9bac29c39c2d327ce8341e8134',
#   'name': 'Victoria Square',
#   'latitude': 54.598203,
#   'longitude': -5.924033,
#   'timestamp': '2025-04-15T18:09:32.772519Z',
#   'free_bikes': 3,
#   'empty_slots': 8,
#   'uid': '20756719',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'b1f04ac54af242f0254fb0d213e8ebb3',
#   'name': 'Lisnasharragh Leisure Centre',
#   'latitude': 54.577839,
#   'longitude': -5.881805,
#   'timestamp': '2025-04-15T18:09:32.772653Z',
#   'free_bikes': 2,
#   'empty_slots': 11,
#   'uid': '95021271',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'b2167d1f8a1421b62d74ea0e167e2e86',
#   'name': 'Shankill Leisure Centre / Shankill Road',
#   'latitude': 54.603687,
#   'longitude': -5.944403,
#   'timestamp': '2025-04-15T18:09:32.772404Z',
#   'free_bikes': 1,
#   'empty_slots': 17,
#   'uid': '20756448',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'b28b6c844a93f5def0edd15f8d7bf017',
#   'name': 'Olympia',
#   'latitude': 54.583056,
#   'longitude': -5.956993,
#   'timestamp': '2025-04-15T18:09:32.772672Z',
#   'free_bikes': 1,
#   'empty_slots': 15,
#   'uid': '121249423',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'b3279fbaa775e09bb8b66012f80abf5a',
#   'name': 'CS Lewis',
#   'latitude': 54.598305,
#   'longitude': -5.890582,
#   'timestamp': '2025-04-15T18:09:32.771778Z',
#   'free_bikes': 15,
#   'empty_slots': 1,
#   'uid': '20754188',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'ba23ad885ab065b254b8a940980d52ca',
#   'name': 'Fraser Pass',
#   'latitude': 54.600337,
#   'longitude': -5.905516,
#   'timestamp': '2025-04-15T18:09:32.771994Z',
#   'free_bikes': 1,
#   'empty_slots': 13,
#   'uid': '20755535',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'cbe0f01a35300746c22f93f6dc438e1d',
#   'name': 'Sandown Road',
#   'latitude': 54.594131,
#   'longitude': -5.868545,
#   'timestamp': '2025-04-15T18:09:32.772817Z',
#   'free_bikes': 2,
#   'empty_slots': 6,
#   'uid': '389634668',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'd01e844ae2cc125f5315c344491e19e5',
#   'name': 'Alfred Street',
#   'latitude': 54.594634,
#   'longitude': -5.927441,
#   'timestamp': '2025-04-15T18:09:32.771635Z',
#   'free_bikes': 3,
#   'empty_slots': 12,
#   'uid': '20751801',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'd412a3eb183b7113ff5ec28eb6b562e8',
#   'name': 'Donegall Quay',
#   'latitude': 54.601437,
#   'longitude': -5.921996,
#   'timestamp': '2025-04-15T18:09:32.771938Z',
#   'free_bikes': 2,
#   'empty_slots': 14,
#   'uid': '20755301',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'd873badf682d23aaa171313c0c6973af',
#   'name': 'Cathedral Gardens',
#   'latitude': 54.60368,
#   'longitude': -5.929345,
#   'timestamp': '2025-04-15T18:09:32.771834Z',
#   'free_bikes': 1,
#   'empty_slots': 18,
#   'uid': '20754597',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'dcd2485cbb0056140bab0700d1735d77',
#   'name': 'Stranmillis',
#   'latitude': 54.574854,
#   'longitude': -5.932134,
#   'timestamp': '2025-04-15T18:09:32.772447Z',
#   'free_bikes': 5,
#   'empty_slots': 8,
#   'uid': '20756503',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'dce1e20d7e09fcaff649fe373933af8a',
#   'name': 'Odyssey / Sydenham Road',
#   'latitude': 54.603923,
#   'longitude': -5.917243,
#   'timestamp': '2025-04-15T18:09:32.772144Z',
#   'free_bikes': 2,
#   'empty_slots': 20,
#   'uid': '20756085',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'de687ed226fad2886d641ea708e7282e',
#   'name': 'Great Victoria Street / Hope Street',
#   'latitude': 54.593469,
#   'longitude': -5.934409,
#   'timestamp': '2025-04-15T18:09:32.772058Z',
#   'free_bikes': 5,
#   'empty_slots': 10,
#   'uid': '20755892',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'e50e9ac63d4b7e1ff5e3c6735fd4f6a1',
#   'name': 'Girdwood Community Hub / Cliftonville Park Avenue',
#   'latitude': 54.611849,
#   'longitude': -5.942139,
#   'timestamp': '2025-04-15T18:09:32.772044Z',
#   'free_bikes': 0,
#   'empty_slots': 14,
#   'uid': '20755849',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'e6334864bee916cd07ed9eafb0ab5ec7',
#   'name': 'Lanyon Station Mays Meadow',
#   'latitude': 54.595321,
#   'longitude': -5.91646,
#   'timestamp': '2025-04-15T18:09:32.771852Z',
#   'free_bikes': 0,
#   'empty_slots': 19,
#   'uid': '20754700',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'e7bc242e7b81a9091ab625e9403680fa',
#   'name': 'College Square East',
#   'latitude': 54.597142,
#   'longitude': -5.934827,
#   'timestamp': '2025-04-15T18:09:32.772596Z',
#   'free_bikes': 2,
#   'empty_slots': 11,
#   'uid': '26051356',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'eb405bd827607e718ed7873e2a88f2f9',
#   'name': 'Drumglass',
#   'latitude': 54.575364,
#   'longitude': -5.955373,
#   'timestamp': '2025-04-15T18:09:32.772779Z',
#   'free_bikes': 6,
#   'empty_slots': 0,
#   'uid': '314224868',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0},
#  {'id': 'belfastbikes-belfast',
#   'station_id': 'fc6fb7a4026e37418578fdf54fdcb826',
#   'name': 'Elms Drive',
#   'latitude': 54.576116,
#   'longitude': -5.942574,
#   'timestamp': '2025-04-15T18:09:32.772725Z',
#   'free_bikes': 0,
#   'empty_slots': 18,
#   'uid': '244525787',
#   'renting': 0,
#   'returning': 0,
#   'last_updated': 0,
#   'address': None,
#   'has_ebikes': 0,
#   'ebikes': 0,
#   'normal_bikes': 0}]

# %%
network_location = network.get("location", {})

                    streaming_data =  {
                    "id": network.get("id"),
                    "name": network.get("name"),
                    "latitude": network_location.get("latitude"),
                    "longitude": network_location.get("longitude"),
                    "city": network_location.get("city"),
                    "country": network_location.get("country"),
                    "company": network.get("company")[0]
                    }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 92
#       1 all_networks = {
#       2     "networks": [
#       3         {
#       4             "id": "abu-dhabi-careem-bike",
#       5             "name": "Abu Dhabi Careem BIKE",
#       6             "location": {
#       7                 "latitude": 24.4866,
#       8                 "longitude": 54.3728,
#       9                 "city": "Abu Dhabi",
#      10                 "country": "AE"
#      11             },
#      12             "href": "/v2/networks/abu-dhabi-careem-bike",
#      13             "company": [
#      14                 "Careem"
#      15             ],
#      16             "gbfs_href": "https://dubai.publicbikesystem.net/customer/gbfs/v2/en/gbfs.json"
#      17         },
#      18         {
#      19             "id": "acces-velo-saguenay",
#      20             "name": "Accès Vélo",
#      21             "location": {
#      22                 "latitude": 48.433333,
#      23                 "longitude": -71.083333,
#      24                 "city": "Saguenay",
#      25                 "country": "CA"
#      26             },
#      27             "href": "/v2/networks/acces-velo-saguenay",
#      28             "company": [
#      29                 "PBSC Urban Solutions"
#      30             ],
#      31             "gbfs_href": "https://saguenay.publicbikesystem.net/customer/gbfs/v2/gbfs.json"
#      32         },
#      33         {
#      34             "id": "aksu",
#      35             "name": "Aksu",
#      36             "location": {
#      37                 "latitude": 41.1664,
#      38                 "longitude": 80.2617,
#      39                 "city": "阿克苏市 (Aksu City)",
#      40                 "country": "CN"
#      41             },
#      42             "href": "/v2/networks/aksu",
#      43             "company": [
#      44                 "阿克苏公共服务"
#      45             ]
#      46         },
#      47         {
#      48             "id": "alba",
#      49             "name": "Alba",
#      50             "location": {
#      51                 "latitude": 44.716667,
#      52                 "longitude": 8.083333,
#      53                 "city": "Alba",
#      54                 "country": "IT"
#      55             },
#      56             "href": "/v2/networks/alba",
#      57             "company": [
#      58                 "Comunicare S.r.l."
#      59             ],
#      60             "system": "Bicincittà",
#      61             "source": "https://www.bicincitta.com/frmLeStazioni.aspx?ID=139"
#      62         },
#      63         {
#      64             "id": "albabici",
#      65             "name": "AlbaBici",
#      66             "location": {
#      67                 "latitude": 38.9943,
#      68                 "longitude": -1.8602,
#      69                 "city": "Albacete",
#      70                 "country": "ES"
#      71             },
#      72             "href": "/v2/networks/albabici",
#      73             "company": [
#      74                 "Instituto Tecnológico de Castilla y León (ITCL)"
#      75             ],
#      76             "system": "bicicard"
#      77         },
#      78         {
#      79             "id": "algira",
#      80             "name": "AlGira",
#      81             "location": {
#      82                 "latitude": 39.2082,
#      83                 "longitude": -8.6252,
#      84                 "city": "Almeirim",
#      85                 "country": "PT"
#      86             },
#      87             "href": "/v2/networks/algira",
#      88             "company": [
#      89                 "Município de Almeirim",
#      90                 "Wegoshare, Lda"
#      91             ],
# ---> 92             "ebikes": true
#      93         },
#      94         {
#      95             "id": "almatybike",
#      96             "name": "Almatybike",
#      97             "location": {
#      98                 "latitude": 43.239101,
#      99                 "longitude": 76.9268076,
#     100                 "city": "Almaty",
#     101                 "country": "KZ"
#     102             },
#     103             "href": "/v2/networks/almatybike",
#     104             "company": [
#     105                 "Velobike.kz, LLP",
#     106                 "Smoove"
#     107             ],
#     108             "system": "Velobike"
#     109         },
#     110         {
#     111             "id": "alsa-nextbike-leon",
#     112             "name": "Alsa nextbike León",
#     113             "location": {
#     114                 "latitude": 42.5987263,
#     115                 "longitude": -5.5670959,
#     116                 "city": "León",
#     117                 "country": "ES"
#     118             },
#     119             "href": "/v2/networks/alsa-nextbike-leon",
#     120             "company": [
#     121                 "Leonbici Nextbike Gmbh Y Autobuses Urbanos De Leon S.a. Ute"
#     122             ],
#     123             "system": "Nextbike"
#     124         },
#     125         {
#     126             "id": "ambici-badalona",
#     127             "name": "Ambici",
#     128             "location": {
#     129                 "latitude": 41.447,
#     130                 "longitude": 2.245,
#     131                 "city": "Badalona",
#     132                 "country": "ES"
#     133             },
#     134             "href": "/v2/networks/ambici-badalona",
#     135             "company": [
#     136                 "Nextbike GmbH",
#     137                 "TIER Mobility SE",
#     138                 "Transports Metropolitans de Barcelona",
#     139                 "Projectes i Serveis de Mobilitat S.A"
#     140             ],
#     141             "system": "Ambici"
#     142         },
#     143         {
#     144             "id": "ambici-castelldefels",
#     145             "name": "Ambici",
#     146             "location": {
#     147                 "latitude": 41.2816,
#     148                 "longitude": 1.97678,
#     149                 "city": "Castelldefels",
#     150                 "country": "ES"
#     151             },
#     152             "href": "/v2/networks/ambici-castelldefels",
#     153             "company": [
#     154                 "Nextbike GmbH",
#     155                 "TIER Mobility SE",
#     156                 "Transports Metropolitans de Barcelona",
#     157                 "Projectes i Serveis de Mobilitat S.A"
#     158             ],
#     159             "system": "Ambici"
#     160         },
#     161         {
#     162             "id": "ambici-cornella-de-llobregat",
#     163             "name": "Ambici",
#     164             "location": {
#     165                 "latitude": 41.3585,
#     166                 "longitude": 2.07081,
#     167                 "city": "Cornellà de Llobregat",
#     168                 "country": "ES"
#     169             },
#     170             "href": "/v2/networks/ambici-cornella-de-llobregat",
#     171             "company": [
#     172                 "Nextbike GmbH",
#     173                 "TIER Mobility SE",
#     174                 "Transports Metropolitans de Barcelona",
#     175                 "Projectes i Serveis de Mobilitat S.A"
#     176             ],
#     177             "system": "Ambici"
#     178         },
#     179         {
#     180             "id": "ambici-el-prat-de-llobregat",
#     181             "name": "Ambici",
#     182             "location": {
#     183                 "latitude": 41.3239,
#     184                 "longitude": 2.09317,
#     185                 "city": "El Prat de Llobregat",
#     186                 "country": "ES"
#     187             },
#     188             "href": "/v2/networks/ambici-el-prat-de-llobregat",
#     189             "company": [
#     190                 "Nextbike GmbH",
#     191                 "TIER Mobility SE",
#     192                 "Transports Metropolitans de Barcelona",
#     193                 "Projectes i Serveis de Mobilitat S.A"
#     194             ],
#     195             "system": "Ambici"
#     196         },
#     197         {
#     198             "id": "ambici-esplugues-de-llobregat",
#     199             "name": "Ambici",
#     200             "location": {
#     201                 "latitude": 41.3771,
#     202                 "longitude": 2.08938,
#     203                 "city": "Esplugues de Llobregat",
#     204                 "country": "ES"
#     205             },
#     206             "href": "/v2/networks/ambici-esplugues-de-llobregat",
#     207             "company": [
#     208                 "Nextbike GmbH",
#     209                 "TIER Mobility SE",
#     210                 "Transports Metropolitans de Barcelona",
#     211                 "Projectes i Serveis de Mobilitat S.A"
#     212             ],
#     213             "system": "Ambici"
#     214         },
#     215         {
#     216             "id": "ambici-gava",
#     217             "name": "Ambici",
#     218             "location": {
#     219                 "latitude": 41.303,
#     220                 "longitude": 2.00269,
#     221                 "city": "Gavà",
#     222                 "country": "ES"
#     223             },
#     224             "href": "/v2/networks/ambici-gava",
#     225             "company": [
#     226                 "Nextbike GmbH",
#     227                 "TIER Mobility SE",
#     228                 "Transports Metropolitans de Barcelona",
#     229                 "Projectes i Serveis de Mobilitat S.A"
#     230             ],
#     231             "system": "Ambici"
#     232         },
#     233         {
#     234             "id": "ambici-molins-de-rei",
#     235             "name": "Ambici",
#     236             "location": {
#     237                 "latitude": 41.4132,
#     238                 "longitude": 2.02037,
#     239                 "city": "Molins de Rei",
#     240                 "country": "ES"
#     241             },
#     242             "href": "/v2/networks/ambici-molins-de-rei",
#     243             "company": [
#     244                 "Nextbike GmbH",
#     245                 "TIER Mobility SE",
#     246                 "Transports Metropolitans de Barcelona",
#     247                 "Projectes i Serveis de Mobilitat S.A"
#     248             ],
#     249             "system": "Ambici"
#     250         },
#     251         {
#     252             "id": "ambici-sant-boi-de-llobregat",
#     253             "name": "Ambici",
#     254             "location": {
#     255                 "latitude": 41.3458,
#     256                 "longitude": 2.03404,
#     257                 "city": "Sant Boi de Llobregat",
#     258                 "country": "ES"
#     259             },
#     260             "href": "/v2/networks/ambici-sant-boi-de-llobregat",
#     261             "company": [
#     262                 "Nextbike GmbH",
#     263                 "TIER Mobility SE",
#     264                 "Transports Metropolitans de Barcelona",
#     265                 "Projectes i Serveis de Mobilitat S.A"
#     266             ],
#     267             "system": "Ambici"
#     268         },
#     269         {
#     270             "id": "ambici-sant-joan-despi",
#     271             "name": "Ambici",
#     272             "location": {
#     273                 "latitude": 41.368,
#     274                 "longitude": 2.05635,
#     275                 "city": "Sant Joan Despí",
#     276                 "country": "ES"
#     277             },
#     278             "href": "/v2/networks/ambici-sant-joan-despi",
#     279             "company": [
#     280                 "Nextbike GmbH",
#     281                 "TIER Mobility SE",
#     282                 "Transports Metropolitans de Barcelona",
#     283                 "Projectes i Serveis de Mobilitat S.A"
#     284             ],
#     285             "system": "Ambici"
#     286         },
#     287         {
#     288             "id": "ambici-sant-just-desvern",
#     289             "name": "Ambici",
#     290             "location": {
#     291                 "latitude": 41.3807,
#     292                 "longitude": 2.07496,
#     293                 "city": "Sant Just Desvern",
#     294                 "country": "ES"
#     295             },
#     296             "href": "/v2/networks/ambici-sant-just-desvern",
#     297             "company": [
#     298                 "Nextbike GmbH",
#     299                 "TIER Mobility SE",
#     300                 "Transports Metropolitans de Barcelona",
#     301                 "Projectes i Serveis de Mobilitat S.A"
#     302             ],
#     303             "system": "Ambici"
#     304         },
#     305         {
#     306             "id": "ambici-santa-coloma-de-gramenet",
#     307             "name": "Ambici",
#     308             "location": {
#     309                 "latitude": 41.4459,
#     310                 "longitude": 2.21033,
#     311                 "city": "Santa Coloma de Gramenet",
#     312                 "country": "ES"
#     313             },
#     314             "href": "/v2/networks/ambici-santa-coloma-de-gramenet",
#     315             "company": [
#     316                 "Nextbike GmbH",
#     317                 "TIER Mobility SE",
#     318                 "Transports Metropolitans de Barcelona",
#     319                 "Projectes i Serveis de Mobilitat S.A"
#     320             ],
#     321             "system": "Ambici"
#     322         },
#     323         {
#     324             "id": "ambici-viladecans",
#     325             "name": "Ambici",
#     326             "location": {
#     327                 "latitude": 41.3165,
#     328                 "longitude": 2.01306,
#     329                 "city": "Viladecans",
#     330                 "country": "ES"
#     331             },
#     332             "href": "/v2/networks/ambici-viladecans",
#     333             "company": [
#     334                 "Nextbike GmbH",
#     335                 "TIER Mobility SE",
#     336                 "Transports Metropolitans de Barcelona",
#     337                 "Projectes i Serveis de Mobilitat S.A"
#     338             ],
#     339             "system": "Ambici"
#     340         },
#     341         {
#     342             "id": "andria",
#     343             "name": "Andria in Bici",
#     344             "location": {
#     345                 "latitude": 41.224346932834,
#     346                 "longitude": 16.296983922753956,
#     347                 "city": "Andria",
#     348                 "country": "IT"
#     349             },
#     350             "href": "/v2/networks/andria",
#     351             "company": [
#     352                 "Comunicare S.r.l."
#     353             ],
#     354             "system": "Bicincittà",
#     355             "source": "https://www.bicincitta.com/frmLeStazioni.aspx?ID=192"
#     356         },
#     357         {
#     358             "id": "aral",
#     359             "name": "Aral",
#     360             "location": {
#     361                 "latitude": 40.5577,
#     362                 "longitude": 81.2879,
#     363                 "city": "阿拉尔市 (Aral)",
#     364                 "country": "CN"
#     365             },
#     366             "href": "/v2/networks/aral",
#     367             "company": [
#     368                 "阿克苏公共服务"
#     369             ]
#     370         },
#     371         {
#     372             "id": "arbike",
#     373             "name": "ARbike",
#     374             "location": {
#     375                 "latitude": 43.473333,
#     376                 "longitude": 11.87,
#     377                 "city": "Arezzo",
#     378                 "country": "IT"
#     379             },
#     380             "href": "/v2/networks/arbike",
#     381             "company": [
#     382                 "Comunicare S.r.l."
#     383             ],
#     384             "system": "Bicincittà",
#     385             "source": "https://www.bicincitta.com/frmLeStazioni.aspx?ID=84"
#     386         },
#     387         {
#     388             "id": "arriva-nitra",
#     389             "name": "Arriva",
#     390             "location": {
#     391                 "latitude": 48.3088,
#     392                 "longitude": 18.0783,
#     393                 "city": "Nitra",
#     394                 "country": "SK"
#     395             },
#     396             "href": "/v2/networks/arriva-nitra",
#     397             "company": [
#     398                 "Nextbike GmbH"
#     399             ]
#     400         },
#     401         {
#     402             "id": "arval-scandicci",
#     403             "name": "ARVAL",
#     404             "location": {
#     405                 "latitude": 43.7701,
#     406                 "longitude": 11.1592,
#     407                 "city": "Scandicci",
#     408                 "country": "IT"
#     409             },
#     410             "href": "/v2/networks/arval-scandicci",
#     411             "company": [
#     412                 "Nextbike GmbH"
#     413             ],
#     414             "system": "Nextbike"
#     415         },
#     416         {
#     417             "id": "ascoli-piceno",
#     418             "name": "Ascoli Piceno",
#     419             "location": {
#     420                 "latitude": 42.85,
#     421                 "longitude": 13.583333,
#     422                 "city": "Ascoli Piceno",
#     423                 "country": "IT"
#     424             },
#     425             "href": "/v2/networks/ascoli-piceno",
#     426             "company": [
#     427                 "Comunicare S.r.l."
#     428             ],
#     429             "system": "Bicincittà",
#     430             "source": "https://www.bicincitta.com/frmLeStazioni.aspx?ID=73"
#     431         },
#     432         {
#     433             "id": "athens-bikes",
#     434             "name": "AthensBikes",
#     435             "location": {
#     436                 "latitude": 37.9838,
#     437                 "longitude": 23.7275,
#     438                 "city": "Athens",
#     439                 "country": "GR"
#     440             },
#     441             "href": "/v2/networks/athens-bikes",
#     442             "company": [
#     443                 "Brainbox Technology",
#     444                 "Smoove SAS"
#     445             ],
#     446             "system": "EasyBike"
#     447         },
#     448         {
#     449             "id": "auxrmlevelo",
#     450             "name": "AuxR_M le vélo",
#     451             "location": {
#     452                 "latitude": 47.797221,
#     453                 "longitude": 3.572376,
#     454                 "city": "Auxerre",
#     455                 "country": "FR"
#     456             },
#     457             "href": "/v2/networks/auxrmlevelo",
#     458             "company": [
#     459                 "Fifteen SAS"
#     460             ],
#     461             "system": "Fifteen"
#     462         },
#     463         {
#     464             "id": "avelo-quebec",
#     465             "name": "àVélo",
#     466             "location": {
#     467                 "latitude": 46.81305,
#     468                 "longitude": -71.2168,
#     469                 "city": "Québec",
#     470                 "country": "CA"
#     471             },
#     472             "href": "/v2/networks/avelo-quebec",
#     473             "company": [
#     474                 "PBSC Urban Solutions"
#     475             ],
#     476             "gbfs_href": "https://quebec.publicbikesystem.net/customer/gbfs/v2/gbfs.json"
#     477         },
#     478         {
#     479             "id": "aventura",
#     480             "name": "Aventura BCycle",
#     481             "location": {
#     482                 "latitude": 25.95711,
#     483                 "longitude": -80.1395,
#     484                 "city": "Aventura, FL",
#     485                 "country": "US"
#     486             },
#     487             "href": "/v2/networks/aventura",
#     488             "company": [
#     489                 "BCycle, LLC"
#     490             ],
#     491             "system": "BCycle",
#     492             "gbfs_href": "https://gbfs.bcycle.com/bcycle_aventura/gbfs.json"
#     493         },
#     494         {
#     495             "id": "aviles-en-bici",
#     496             "name": "Avilés en Bici",
#     497             "location": {
#     498                 "latitude": 43.5554,
#     499                 "longitude": -5.9222,
#     500                 "city": "Avilés",
#     501                 "country": "ES"
#     502             },
#     503             "href": "/v2/networks/aviles-en-bici",
#     504             "company": [
#     505                 "Instituto Tecnológico de Castilla y León (ITCL)"
#     506             ],
#     507             "system": "bicicard"
#     508         },
#     509         {
#     510             "id": "aw-bike",
#     511             "name": "AW-bike Ahrweiler",
#     512             "location": {
#     513                 "latitude": 50.5452,
#     514                 "longitude": 7.1212,
#     515                 "city": "Ahrweiler",
#     516                 "country": "DE"
#     517             },
#     518             "href": "/v2/networks/aw-bike",
#     519             "company": [
#     520                 "nextbike GmbH"
#     521             ],
#     522             "gbfs_href": "https://gbfs.nextbike.net/maps/gbfs/v2/nextbike_rh/gbfs.json"
#     523         },
#     524         {
#     525             "id": "baksi-antalya",
#     526             "name": "Baksi",
#     527             "location": {
#     528                 "latitude": 36.862048,
#     529                 "longitude": 30.638866,
#     530                 "city": "Antalya",
#     531                 "country": "TR"
#     532             },
#     533             "href": "/v2/networks/baksi-antalya",
#     534             "company": [
#     535                 "Baksi Bike Sharing System"
#     536             ],
#     537             "system": "Baksi"
#     538         },
#     539         {
#     540             "id": "baksi-cabis",
#     541             "name": "Çabis",
#     542             "location": {
#     543                 "latitude": 40.1531,
#     544                 "longitude": 26.4146,
#     545                 "city": "Çanakkale",
#     546                 "country": "TR"
#     547             },
#     548             "href": "/v2/networks/baksi-cabis",
#     549             "company": [
#     550                 "Baksi Bike Sharing System"
#     551             ],
#     552             "system": "Baksi"
#     553         },
#     554         {
#     555             "id": "baksi-nilesplit",
#     556             "name": "Nilesplit",
#     557             "location": {
#     558                 "latitude": 40.2127,
#     559                 "longitude": 28.9627,
#     560                 "city": "Nilüfer",
#     561                 "country": "TR"
#     562             },
#     563             "href": "/v2/networks/baksi-nilesplit",
#     564             "company": [
#     565                 "Baksi Bike Sharing System"
#     566             ],
#     567             "system": "Baksi"
#     568         },
#     569         {
#     570             "id": "batumvelo",
#     571             "name": "Batumvelo",
#     572             "location": {
#     573                 "latitude": 41.660906,
#     574                 "longitude": 41.678835,
#     575                 "city": "Batumi",
#     576                 "country": "GE"
#     577             },
#     578             "href": "/v2/networks/batumvelo",
#     579             "company": [
#     580                 "Smoove"
#     581             ],
#     582             "system": "Smoove"
#     583         },
#     584         {
#     585             "id": "bay-wheels",
#     586             "name": "Bay Wheels",
#     587             "location": {
#     588                 "latitude": 37.7141454,
#     589                 "longitude": -122.25,
#     590                 "city": "San Francisco Bay Area, CA",
#     591                 "country": "US"
#     592             },
#     593             "href": "/v2/networks/bay-wheels",
#     594             "company": [
#     595                 "Motivate LLC"
#     596             ],
#     597             "gbfs_href": "https://gbfs.baywheels.com/gbfs/gbfs.json"
#     598         },
#     599         {
#     600             "id": "bealler",
#     601             "name": "Pedaleando por Aller (BeALLER)",
#     602             "location": {
#     603                 "latitude": 43.1482,
#     604                 "longitude": -5.6295,
#     605                 "city": "Aller",
#     606                 "country": "ES"
#     607             },
#     608             "href": "/v2/networks/bealler",
#     609             "company": [
#     610                 "Instituto Tecnológico de Castilla y León (ITCL)"
#     611             ],
#     612             "system": "bicicard"
#     613         },
#     614         {
#     615             "id": "belfastbikes-belfast",
#     616             "name": "BelfastBikes",
#     617             "location": {
#     618                 "latitude": 54.5969,
#     619                 "longitude": -5.92918,
#     620                 "city": "Belfast",
#     621                 "country": "GB"
#     622             },
#     623             "href": "/v2/networks/belfastbikes-belfast",
#     624             "company": [
#     625                 "Nextbike GmbH"
#     626             ],
#     627             "system": "Nextbike"
#     628         },
#     629         {
#     630             "id": "bentonville",
#     631             "name": "Bentonville BCycle",
#     632             "location": {
#     633                 "latitude": 36.3605,
#     634                 "longitude": -94.1996,
#     635                 "city": "Bentonville, AR",
#     636                 "country": "US"
#     637             },
#     638             "href": "/v2/networks/bentonville",
#     639             "company": [
#     640                 "BCycle, LLC"
#     641             ],
#     642             "system": "BCycle",
#     643             "gbfs_href": "https://gbfs.bcycle.com/bcycle_bentonville/gbfs.json"
#     644         },
#     645         {
#     646             "id": "bergen-bysykkel",
#     647             "name": "Bysykkel",
#     648             "location": {
#     649                 "latitude": 60.391263,
#     650                 "longitude": 5.322054,
#     651                 "city": "Bergen",
#     652                 "country": "NO"
#     653             },
#     654             "href": "/v2/networks/bergen-bysykkel",
#     655             "company": [
#     656                 "Urban Sharing AS"
#     657             ],
#     658             "gbfs_href": "https://gbfs.urbansharing.com/bergenbysykkel.no/gbfs.json"
#     659         },
#     660         {
#     661             "id": "bergisches-e-bike",
#     662             "name": "Bergisches e-Bike",
#     663             "location": {
#     664                 "latitude": 51.0192,
#     665                 "longitude": 7.18025,
#     666                 "city": "Bergisches e-Bike",
#     667                 "country": "DE"
#     668             },
#     669             "href": "/v2/networks/bergisches-e-bike",
#     670             "company": [
#     671                 "Nextbike GmbH"
#     672             ],
#     673             "system": "Nextbike"
#     674         },
#     675         {
#     676             "id": "beryl-bcp",
#     677             "name": "Beryl - Bournemouth, Christchurch and Poole",
#     678             "location": {
#     679                 "latitude": 50.7196,
#     680                 "longitude": -1.8734,
#     681                 "city": "Bournemouth, Christchurch and Poole",
#     682                 "country": "GB"
#     683             },
#     684             "href": "/v2/networks/beryl-bcp",
#     685             "company": [
#     686                 "Beryl"
#     687             ],
#     688             "gbfs_href": "https://gbfs.beryl.cc/v2_2/BCP/gbfs.json"
#     689         },
#     690         {
#     691             "id": "beryl-brighton",
#     692             "name": "Beryl - Brighton",
#     693             "location": {
#     694                 "latitude": 50.8222,
#     695                 "longitude": -0.1403,
#     696                 "city": "Brighton",
#     697                 "country": "GB"
#     698             },
#     699             "href": "/v2/networks/beryl-brighton",
#     700             "company": [
#     701                 "Beryl"
#     702             ],
#     703             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Brighton/gbfs.json"
#     704         },
#     705         {
#     706             "id": "beryl-cornwall",
#     707             "name": "Beryl - Cornwall",
#     708             "location": {
#     709                 "latitude": 50.2616,
#     710                 "longitude": -5.051,
#     711                 "city": "Cornwall",
#     712                 "country": "GB"
#     713             },
#     714             "href": "/v2/networks/beryl-cornwall",
#     715             "company": [
#     716                 "Beryl"
#     717             ],
#     718             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Cornwall/gbfs.json"
#     719         },
#     720         {
#     721             "id": "beryl-dorchester-weymouth-portland",
#     722             "name": "Beryl - Dorchester, Weymouth and Portland",
#     723             "location": {
#     724                 "latitude": 50.6085,
#     725                 "longitude": -2.454,
#     726                 "city": "Dorchester, Weymouth and Portland",
#     727                 "country": "GB"
#     728             },
#     729             "href": "/v2/networks/beryl-dorchester-weymouth-portland",
#     730             "company": [
#     731                 "Beryl"
#     732             ],
#     733             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Weymouth/gbfs.json"
#     734         },
#     735         {
#     736             "id": "beryl-eastleigh",
#     737             "name": "Beryl - Eastleigh",
#     738             "location": {
#     739                 "latitude": 50.9691,
#     740                 "longitude": -1.3603,
#     741                 "city": "Eastleigh",
#     742                 "country": "GB"
#     743             },
#     744             "href": "/v2/networks/beryl-eastleigh",
#     745             "company": [
#     746                 "Beryl"
#     747             ],
#     748             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Eastleigh/gbfs.json"
#     749         },
#     750         {
#     751             "id": "beryl-greater-manchester",
#     752             "name": "Beryl - Greater Manchester",
#     753             "location": {
#     754                 "latitude": 53.4795,
#     755                 "longitude": -2.2436,
#     756                 "city": "Greater Manchester",
#     757                 "country": "GB"
#     758             },
#     759             "href": "/v2/networks/beryl-greater-manchester",
#     760             "company": [
#     761                 "Beryl"
#     762             ],
#     763             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Greater_Manchester/gbfs.json"
#     764         },
#     765         {
#     766             "id": "beryl-guildford",
#     767             "name": "Beryl - Guildford",
#     768             "location": {
#     769                 "latitude": 51.2397,
#     770                 "longitude": -0.5764,
#     771                 "city": "Guildford",
#     772                 "country": "GB"
#     773             },
#     774             "href": "/v2/networks/beryl-guildford",
#     775             "company": [
#     776                 "Beryl"
#     777             ],
#     778             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Guildford/gbfs.json"
#     779         },
#     780         {
#     781             "id": "beryl-hereford",
#     782             "name": "Beryl - Hereford",
#     783             "location": {
#     784                 "latitude": 52.0549,
#     785                 "longitude": -2.7156,
#     786                 "city": "Hereford",
#     787                 "country": "GB"
#     788             },
#     789             "href": "/v2/networks/beryl-hereford",
#     790             "company": [
#     791                 "Beryl"
#     792             ],
#     793             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Hereford/gbfs.json"
#     794         },
#     795         {
#     796             "id": "beryl-hertsmere",
#     797             "name": "Beryl - Hertsmere",
#     798             "location": {
#     799                 "latitude": 51.6577,
#     800                 "longitude": -0.2695,
#     801                 "city": "Hertsmere",
#     802                 "country": "GB"
#     803             },
#     804             "href": "/v2/networks/beryl-hertsmere",
#     805             "company": [
#     806                 "Beryl"
#     807             ],
#     808             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Hertsmere/gbfs.json"
#     809         },
#     810         {
#     811             "id": "beryl-leeds",
#     812             "name": "Beryl - Leeds",
#     813             "location": {
#     814                 "latitude": 53.7971,
#     815                 "longitude": -1.5438,
#     816                 "city": "Leeds",
#     817                 "country": "GB"
#     818             },
#     819             "href": "/v2/networks/beryl-leeds",
#     820             "company": [
#     821                 "Beryl"
#     822             ],
#     823             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Leeds/gbfs.json"
#     824         },
#     825         {
#     826             "id": "beryl-norwich",
#     827             "name": "Beryl - Norwich",
#     828             "location": {
#     829                 "latitude": 52.6288,
#     830                 "longitude": 1.2934,
#     831                 "city": "Norwich",
#     832                 "country": "GB"
#     833             },
#     834             "href": "/v2/networks/beryl-norwich",
#     835             "company": [
#     836                 "Beryl"
#     837             ],
#     838             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Norwich/gbfs.json"
#     839         },
#     840         {
#     841             "id": "beryl-plymouth",
#     842             "name": "Beryl - Plymouth",
#     843             "location": {
#     844                 "latitude": 50.3714,
#     845                 "longitude": -4.1421,
#     846                 "city": "Plymouth",
#     847                 "country": "GB"
#     848             },
#     849             "href": "/v2/networks/beryl-plymouth",
#     850             "company": [
#     851                 "Beryl"
#     852             ],
#     853             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Plymouth/gbfs.json"
#     854         },
#     855         {
#     856             "id": "beryl-stevenage",
#     857             "name": "Beryl - Stevenage",
#     858             "location": {
#     859                 "latitude": 51.9059,
#     860                 "longitude": -0.1905,
#     861                 "city": "Stevenage",
#     862                 "country": "GB"
#     863             },
#     864             "href": "/v2/networks/beryl-stevenage",
#     865             "company": [
#     866                 "Beryl"
#     867             ],
#     868             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Stevenage/gbfs.json"
#     869         },
#     870         {
#     871             "id": "beryl-watford",
#     872             "name": "Beryl - Watford",
#     873             "location": {
#     874                 "latitude": 51.6556,
#     875                 "longitude": -0.3953,
#     876                 "city": "Watford",
#     877                 "country": "GB"
#     878             },
#     879             "href": "/v2/networks/beryl-watford",
#     880             "company": [
#     881                 "Beryl"
#     882             ],
#     883             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Watford/gbfs.json"
#     884         },
#     885         {
#     886             "id": "beryl-west-midlands",
#     887             "name": "Beryl - West Midlands",
#     888             "location": {
#     889                 "latitude": 52.4798,
#     890                 "longitude": -1.9014,
#     891                 "city": "West Midlands",
#     892                 "country": "GB"
#     893             },
#     894             "href": "/v2/networks/beryl-west-midlands",
#     895             "company": [
#     896                 "Beryl"
#     897             ],
#     898             "gbfs_href": "https://gbfs.beryl.cc/v2_2/West_Midlands/gbfs.json"
#     899         },
#     900         {
#     901             "id": "beryl-worcester",
#     902             "name": "Beryl - Worcester",
#     903             "location": {
#     904                 "latitude": 52.1912,
#     905                 "longitude": -2.2206,
#     906                 "city": "Worcester",
#     907                 "country": "GB"
#     908             },
#     909             "href": "/v2/networks/beryl-worcester",
#     910             "company": [
#     911                 "Beryl"
#     912             ],
#     913             "gbfs_href": "https://gbfs.beryl.cc/v2_2/Worcester/gbfs.json"
#     914         },
#     915         {
#     916             "id": "bia",
#     917             "name": "BIA",
#     918             "location": {
#     919                 "latitude": 40.8599,
#     920                 "longitude": -8.6246,
#     921                 "city": "Ovar",
#     922                 "country": "PT"
#     923             },
#     924             "href": "/v2/networks/bia",
#     925             "company": [
#     926                 "Município de Ovar",
#     927                 "Share2Go - Mobilidade Partilhada, Sociedade Unipessoal Lda"
#     928             ],
#     929             "ebikes": true
#     930         },
#     931         {
#     932             "id": "bianzone-in-bici",
#     933             "name": "Bianzone in Bici",
#     934             "location": {
#     935                 "latitude": 46.188197,
#     936                 "longitude": 10.109354,
#     937                 "city": "Bianzone",
#     938                 "country": "IT"
#     939             },
#     940             "href": "/v2/networks/bianzone-in-bici",
#     941             "company": [
#     942                 "Comunicare S.r.l."
#     943             ],
#     944             "system": "Bicincittà",
#     945             "source": "https://www.bicincitta.com/frmLeStazioni.aspx?ID=147"
#     946         },
#     947         {
#     948             "id": "biba",
#     949             "name": "BiBa",
#     950             "location": {
#     951                 "latitude": 38.878,
#     952                 "longitude": -6.9701,
#     953                 "city": "Badajoz",
#     954                 "country": "ES"
#     955             },
#     956             "href": "/v2/networks/biba",
#     957             "company": [
#     958                 "Instituto Tecnológico de Castilla y León (ITCL)"
#     959             ],
#     960             "system": "bicicard"
#     961         },
#     962         {
#     963             "id": "bibo",
#     964             "name": "BIBO",
#     965             "location": {
#     966                 "latitude": 40.4125,
#     967                 "longitude": -3.8909,
#     968                 "city": "Boadilla del Monte",
#     969                 "country": "ES"
#     970             },
#     971             "href": "/v2/networks/bibo",
#     972             "company": [
#     973                 "Movilidad Urbana Sostenible SLU"
#     974             ]
#     975         },
#     976         {
#     977             "id": "bici-bolzano",
#     978             "name": "Bici Bolzano",
#     979             "location": {
#     980                 "latitude": 46.49,
#     981                 "longitude": 11.3401,
#     982                 "city": "Bolzano",
#     983                 "country": "IT"
#     984             },
#     985             "href": "/v2/networks/bici-bolzano",
#     986             "company": [
#     987                 "Ecospazio Logiss S.r.l."
#     988             ]
#     989         },
#     990         {
#     991             "id": "bici-co",
#     992             "name": "BICI&CO",
#     993             "location": {
#     994                 "latitude": 45.8080597,
#     995                 "longitude": 9.0851765,
#     996                 "city": "Como",
#     997                 "country": "IT"
#     998             },
#     999             "href": "/v2/networks/bici-co",
#    1000             "company": [
#    1001                 "Comunicare S.r.l."
#    1002             ],
#    1003             "system": "Bicincittà",
#    1004             "source": "https://www.bicincitta.com/frmLeStazioni.aspx?ID=157"
#    1005         },
#    1006         {
#    1007             "id": "bici-ferrol-terra",
#    1008             "name": "BiciFerrolTerra",
#    1009             "location": {
#    1010                 "latitude": 43.4896,
#    1011                 "longitude": -8.2193,
#    1012                 "city": "Ferrol - Narón",
#    1013                 "country": "ES"
#    1014             },
#    1015             "href": "/v2/networks/bici-ferrol-terra",
#    1016             "company": [
#    1017                 "2K SYSTEMS, S.L.",
#    1018                 "Bike Works Naron"
#    1019             ]
#    1020         },
#    1021         {
#    1022             "id": "bici-in-busto",
#    1023             "name": "Bici in Busto",
#    1024             "location": {
#    1025                 "latitude": 45.610555,
#    1026                 "longitude": 8.852062,
#    1027                 "city": "Busto Arsizio",
#    1028                 "country": "IT"
#    1029             },
#    1030             "href": "/v2/networks/bici-in-busto",
#    1031             "company": [
#    1032                 "Comunicare S.r.l."
#    1033             ],
#    1034             "system": "Bicincittà",
#    1035             "source": "https://www.bicincitta.com/frmLeStazioni.aspx?ID=66"
#    1036         },
#    1037         {
#    1038             "id": "bici-perugia",
#    1039             "name": "Bici Perugia",
#    1040             "location": {
#    1041                 "latitude": 43.1107168,
#    1042                 "longitude": 12.3908279,
#    1043                 "city": "Perugia",
#    1044                 "country": "IT"
#    1045             },
#    1046             "href": "/v2/networks/bici-perugia",
#    1047             "company": [
#    1048                 "Comunicare S.r.l."
#    1049             ],
#    1050             "system": "Bicincittà",
#    1051             "source": "https://www.bicincitta.com/frmLeStazioni.aspx?ID=122"
#    1052         },
#    1053         {
#    1054             "id": "bicialcazar",
#    1055             "name": "BiciAlcázar",
#    1056             "location": {
#    1057                 "latitude": 39.3901,
#    1058                 "longitude": -3.2101,
#    1059                 "city": "Alcázar de San Juan",
#    1060                 "country": "ES"
#    1061             },
#    1062             "href": "/v2/networks/bicialcazar",
#    1063             "company": [
#    1064                 "Instituto Tecnológico de Castilla y León (ITCL)"
#    1065             ],
#    1066             "system": "bicicard"
#    1067         },
#    1068         {
#    1069             "id": "biciarousa",
#    1070             "name": "BiciArousa",
#    1071             "location": {
#    1072                 "latitude": 42.5521,
#    1073                 "longitude": -8.8666,
#    1074                 "city": "A Illa de Arousa",
#    1075                 "country": "ES"
#    1076             },
#    1077             "href": "/v2/networks/biciarousa",
#    1078             "company": [
#    1079                 "Instituto Tecnológico de Castilla y León (ITCL)"
#    1080             ],
#    1081             "system": "bicicard"
#    1082         },
#    1083         {
#    1084             "id": "biciarteixo",
#    1085             "name": "biciArteixo",
#    1086             "location": {
#    1087                 "latitude": 43.3053,
#    1088                 "longitude": -8.5069,
#    1089                 "city": "Arteixo",
#    1090                 "country": "ES"
#    1091             },
#    1092             "href": "/v2/networks/biciarteixo",
#    1093             "company": [
#    1094                 "Servizos Urbanos Municipais de Arteixo, S. A."
#    1095             ],
#    1096             "system": "Nextbike"
#    1097         },
#    1098         {
#    1099             "id": "bicibur",
#    1100             "name": "BiciBur",
#    1101             "location": {
#    1102                 "latitude": 42.34392,
#    1103                 "longitude": -3.69697,
#    1104                 "city": "Burgos",
#    1105                 "country": "ES"
#    1106             },
#    1107             "href": "/v2/networks/bicibur",
#    1108             "company": [
#    1109                 "Instituto Tecnológico de Castilla y León (ITCL)"
#    1110             ]
#    1111         },
#    1112         {
#    1113             "id": "bicicas",
#    1114             "name": "Bicicas",
#    1115             "location": {
#    1116                 "latitude": 39.9856,
#    1117                 "longitude": -0.0389,
#    1118                 "city": "Castelló de la Plana",
#    1119                 "country": "ES"
#    1120             },
#    1121             "href": "/v2/networks/bicicas",
#    1122             "company": [
#    1123                 "Maquiver S.L.U.",
#    1124                 "Ajuntament de Castelló de la Plana"
#    1125             ]
#    1126         },
#    1127         {
#    1128             "id": "bicicletar",
#    1129             "name": "Bicicletar",
#    1130             "location": {
#    1131                 "latitude": -3.7321944,
#    1132                 "longitude": -38.510347,
#    1133                 "city": "Fortaleza",
#    1134                 "country": "BR"
#    1135             },
#    1136             "href": "/v2/networks/bicicletar",
#    1137             "company": [
#    1138                 "Mobilicidade Tecnologia LTD",
#    1139                 "Grupo Serttel LTDA"
#    1140             ],
#    1141             "system": "Samba"
#    1142         },
#    1143         {
#    1144             "id": "bicicorunha",
#    1145             "name": "Bicicoruña",
#    1146             "location": {
#    1147                 "latitude": 43.3623,
#    1148                 "longitude": -8.4115,
#    1149                 "city": "A Coruña",
#    1150                 "country": "ES"
#    1151             },
#    1152             "href": "/v2/networks/bicicorunha",
#    1153             "company": [
#    1154                 "PBSC Urban Solutions"
#    1155             ],
#    1156             "gbfs_href": "https://acoruna.publicbikesystem.net/customer/gbfs/v2/gbfs.json"
#    1157         },
#    1158         {
#    1159             "id": "bicicuenca",
#    1160             "name": "Bici Pública Cuenca",
#    1161             "location": {
#    1162                 "latitude": -2.897,
#    1163                 "longitude": -79.0038,
#    1164                 "city": "Cuenca",
#    1165                 "country": "EC"
#    1166             },
#    1167             "href": "/v2/networks/bicicuenca",
#    1168             "company": [
#    1169                 "Mobilicidade Tecnologia LTD",
#    1170                 "Grupo Serttel LTDA"
#    1171             ],
#    1172             "system": "Samba"
#    1173         },
#    1174         {
#    1175             "id": "bicielx",
#    1176             "name": "Bicielx",
#    1177             "location": {
#    1178                 "latitude": 38.2665,
#    1179                 "longitude": -0.7,
#    1180                 "city": "Elx",
#    1181                 "country": "ES"
#    1182             },
#    1183             "href": "/v2/networks/bicielx",
#    1184             "company": [
#    1185                 "Promociones e Iniciativas Municipales de Elche, S.A."
#    1186             ]
#    1187         },
#    1188         {
#    1189             "id": "bicikelj",
#    1190             "name": "Bicikelj",
#    1191             "location": {
#    1192                 "latitude": 46.05645089999999,
#    1193                 "longitude": 14.5080702,
#    1194                 "city": "Ljubljana",
#    1195                 "country": "SI"
#    1196             },
#    1197             "href": "/v2/networks/bicikelj",
#    1198             "company": [
#    1199                 "JCDecaux"
#    1200             ],
#    1201             "system": "Cyclocity",
#    1202             "license": {
#    1203                 "name": "Open Licence",
#    1204                 "url": "https://developer.jcdecaux.com/#/opendata/licence"
#    1205             },
#    1206             "source": "https://developer.jcdecaux.com"
#    1207         },
#    1208         {
#    1209             "id": "bicilog",
#    1210             "name": "BiciLog",
#    1211             "location": {
#    1212                 "latitude": 42.4658,
#    1213                 "longitude": -2.4402,
#    1214                 "city": "Logroño",
#    1215                 "country": "ES"
#    1216             },
#    1217             "href": "/v2/networks/bicilog",
#    1218             "company": [
# ...
#   11935             "location": {
#   11936                 "latitude": 48.2081743,
#   11937                 "longitude": 16.3738189,
#   11938                 "city": "Wien",
#   11939                 "country": "AT"
#   11940             },
#   11941             "href": "/v2/networks/wienmobil-rad",
#   11942             "company": [
#   11943                 "Nextbike GmbH"
#   11944             ],
#   11945             "system": "Nextbike"
#   11946         },
#   11947         {
#   11948             "id": "winsenrad",
#   11949             "name": "WinsenRad",
#   11950             "location": {
#   11951                 "latitude": 53.3547,
#   11952                 "longitude": 10.2067,
#   11953                 "city": "Winsen (Luhe)",
#   11954                 "country": "DE"
#   11955             },
#   11956             "href": "/v2/networks/winsenrad",
#   11957             "company": [
#   11958                 "Nextbike GmbH"
#   11959             ],
#   11960             "system": "Nextbike"
#   11961         },
#   11962         {
#   11963             "id": "wk-bike-bremen-bremen",
#   11964             "name": "WK-Bike",
#   11965             "location": {
#   11966                 "latitude": 53.0781,
#   11967                 "longitude": 8.80132,
#   11968                 "city": "Bremen",
#   11969                 "country": "DE"
#   11970             },
#   11971             "href": "/v2/networks/wk-bike-bremen-bremen",
#   11972             "company": [
#   11973                 "Nextbike GmbH"
#   11974             ],
#   11975             "system": "Nextbike"
#   11976         },
#   11977         {
#   11978             "id": "wolf-ride-bike-share",
#   11979             "name": "Wolf Ride Bike Share (Stony Brook University)",
#   11980             "location": {
#   11981                 "latitude": 40.9124,
#   11982                 "longitude": -73.1249,
#   11983                 "city": "Stony Brook",
#   11984                 "country": "US"
#   11985             },
#   11986             "href": "/v2/networks/wolf-ride-bike-share",
#   11987             "company": [
#   11988                 "Stony Brook University"
#   11989             ],
#   11990             "gbfs_href": "https://sbu.publicbikesystem.net/customer/gbfs/v2/gbfs.json"
#   11991         },
#   11992         {
#   11993             "id": "wrm-wroclaw",
#   11994             "name": "WRM",
#   11995             "location": {
#   11996                 "latitude": 51.1097,
#   11997                 "longitude": 17.0485,
#   11998                 "city": "Wrocław",
#   11999                 "country": "PL"
#   12000             },
#   12001             "href": "/v2/networks/wrm-wroclaw",
#   12002             "company": [
#   12003                 "Nextbike GmbH"
#   12004             ]
#   12005         },
#   12006         {
#   12007             "id": "wupsi",
#   12008             "name": "wupsiRad Leverkusen",
#   12009             "location": {
#   12010                 "latitude": 51.0732,
#   12011                 "longitude": 7.00814,
#   12012                 "city": "Leverkusen",
#   12013                 "country": "DE"
#   12014             },
#   12015             "href": "/v2/networks/wupsi",
#   12016             "company": [
#   12017                 "Nextbike GmbH"
#   12018             ],
#   12019             "system": "Nextbike"
#   12020         },
#   12021         {
#   12022             "id": "xian-public-bicycle",
#   12023             "name": "Xi'an Public Bicycle",
#   12024             "location": {
#   12025                 "latitude": 34.2688,
#   12026                 "longitude": 108.9458,
#   12027                 "city": "西安 (Xi'an)",
#   12028                 "country": "CN"
#   12029             },
#   12030             "href": "/v2/networks/xian-public-bicycle",
#   12031             "company": [
#   12032                 "西安城市公共自行车服务管理有"
#   12033             ]
#   12034         },
#   12035         {
#   12036             "id": "yelo-velo",
#   12037             "name": "Yélo Vélo",
#   12038             "location": {
#   12039                 "latitude": 46.1591,
#   12040                 "longitude": -1.1509,
#   12041                 "city": "La Rochelle",
#   12042                 "country": "FR"
#   12043             },
#   12044             "href": "/v2/networks/yelo-velo",
#   12045             "company": [
#   12046                 "Communauté d'Agglomération de La Rochelle"
#   12047             ],
#   12048             "license": {
#   12049                 "name": "Licence Ouverte",
#   12050                 "url": "https://www.etalab.gouv.fr/licence-ouverte-open-licence/"
#   12051             }
#   12052         },
#   12053         {
#   12054             "id": "youbike-chiayi-city",
#   12055             "name": "YouBike",
#   12056             "location": {
#   12057                 "latitude": 23.4797,
#   12058                 "longitude": 120.4397,
#   12059                 "city": "台灣 Chiayi City",
#   12060                 "country": "TW"
#   12061             },
#   12062             "href": "/v2/networks/youbike-chiayi-city",
#   12063             "company": [
#   12064                 "YouBike Co., Ltd."
#   12065             ],
#   12066             "system": "YouBike"
#   12067         },
#   12068         {
#   12069             "id": "youbike-hsinchu-city",
#   12070             "name": "YouBike",
#   12071             "location": {
#   12072                 "latitude": 24.8018,
#   12073                 "longitude": 120.9714,
#   12074                 "city": "新竹市 Hsinchu City",
#   12075                 "country": "TW"
#   12076             },
#   12077             "href": "/v2/networks/youbike-hsinchu-city",
#   12078             "company": [
#   12079                 "YouBike Co., Ltd."
#   12080             ],
#   12081             "system": "YouBike"
#   12082         },
#   12083         {
#   12084             "id": "youbike-hsinchu-county",
#   12085             "name": "YouBike",
#   12086             "location": {
#   12087                 "latitude": 24.8269,
#   12088                 "longitude": 121.0129,
#   12089                 "city": "新竹縣 Hsinchu County",
#   12090                 "country": "TW"
#   12091             },
#   12092             "href": "/v2/networks/youbike-hsinchu-county",
#   12093             "company": [
#   12094                 "YouBike Co., Ltd."
#   12095             ],
#   12096             "system": "YouBike"
#   12097         },
#   12098         {
#   12099             "id": "youbike-hsinchu-science-park",
#   12100             "name": "YouBike",
#   12101             "location": {
#   12102                 "latitude": 24.7818,
#   12103                 "longitude": 121.005,
#   12104                 "city": "新竹科學工業園區 Hsinchu Science Park",
#   12105                 "country": "TW"
#   12106             },
#   12107             "href": "/v2/networks/youbike-hsinchu-science-park",
#   12108             "company": [
#   12109                 "YouBike Co., Ltd."
#   12110             ],
#   12111             "system": "YouBike"
#   12112         },
#   12113         {
#   12114             "id": "youbike-kaohsiung-city",
#   12115             "name": "YouBike",
#   12116             "location": {
#   12117                 "latitude": 22.6314,
#   12118                 "longitude": 120.3018,
#   12119                 "city": "高雄市 Kaohsiung City",
#   12120                 "country": "TW"
#   12121             },
#   12122             "href": "/v2/networks/youbike-kaohsiung-city",
#   12123             "company": [
#   12124                 "YouBike Co., Ltd."
#   12125             ],
#   12126             "system": "YouBike"
#   12127         },
#   12128         {
#   12129             "id": "youbike-miaoli-county",
#   12130             "name": "YouBike",
#   12131             "location": {
#   12132                 "latitude": 24.5648,
#   12133                 "longitude": 120.8185,
#   12134                 "city": "台灣 Miaoli County",
#   12135                 "country": "TW"
#   12136             },
#   12137             "href": "/v2/networks/youbike-miaoli-county",
#   12138             "company": [
#   12139                 "YouBike Co., Ltd."
#   12140             ],
#   12141             "system": "YouBike"
#   12142         },
#   12143         {
#   12144             "id": "youbike-new-taipei",
#   12145             "name": "YouBike",
#   12146             "location": {
#   12147                 "latitude": 25.0169826,
#   12148                 "longitude": 121.4627868,
#   12149                 "city": "新北市 New Taipei",
#   12150                 "country": "TW"
#   12151             },
#   12152             "href": "/v2/networks/youbike-new-taipei",
#   12153             "company": [
#   12154                 "YouBike Co., Ltd."
#   12155             ],
#   12156             "system": "YouBike"
#   12157         },
#   12158         {
#   12159             "id": "youbike-pingtung-county",
#   12160             "name": "YouBike",
#   12161             "location": {
#   12162                 "latitude": 22.683,
#   12163                 "longitude": 120.4879,
#   12164                 "city": "屏東縣 Pingtung County",
#   12165                 "country": "TW"
#   12166             },
#   12167             "href": "/v2/networks/youbike-pingtung-county",
#   12168             "company": [
#   12169                 "YouBike Co., Ltd."
#   12170             ],
#   12171             "system": "YouBike"
#   12172         },
#   12173         {
#   12174             "id": "youbike-putian-city",
#   12175             "name": "YouBike",
#   12176             "location": {
#   12177                 "latitude": 25.4504,
#   12178                 "longitude": 119.0126,
#   12179                 "city": "莆田市 (Putian City)",
#   12180                 "country": "CN"
#   12181             },
#   12182             "href": "/v2/networks/youbike-putian-city",
#   12183             "company": [
#   12184                 "YouBike Co., Ltd."
#   12185             ],
#   12186             "system": "YouBike"
#   12187         },
#   12188         {
#   12189             "id": "youbike-taichung",
#   12190             "name": "YouBike",
#   12191             "location": {
#   12192                 "latitude": 24.1477358,
#   12193                 "longitude": 120.6736482,
#   12194                 "city": "臺中市 Taichung City",
#   12195                 "country": "TW"
#   12196             },
#   12197             "href": "/v2/networks/youbike-taichung",
#   12198             "company": [
#   12199                 "YouBike Co., Ltd."
#   12200             ],
#   12201             "system": "YouBike"
#   12202         },
#   12203         {
#   12204             "id": "youbike-tainan-city",
#   12205             "name": "YouBike",
#   12206             "location": {
#   12207                 "latitude": 22.9923,
#   12208                 "longitude": 120.185,
#   12209                 "city": "臺南市 Tainan City",
#   12210                 "country": "TW"
#   12211             },
#   12212             "href": "/v2/networks/youbike-tainan-city",
#   12213             "company": [
#   12214                 "YouBike Co., Ltd."
#   12215             ],
#   12216             "system": "YouBike"
#   12217         },
#   12218         {
#   12219             "id": "youbike-taipei",
#   12220             "name": "YouBike",
#   12221             "location": {
#   12222                 "latitude": 25.0329636,
#   12223                 "longitude": 121.5654268,
#   12224                 "city": "台北市 Taipei City",
#   12225                 "country": "TW"
#   12226             },
#   12227             "href": "/v2/networks/youbike-taipei",
#   12228             "company": [
#   12229                 "YouBike Co., Ltd."
#   12230             ],
#   12231             "system": "YouBike"
#   12232         },
#   12233         {
#   12234             "id": "youbike-taoyuan",
#   12235             "name": "YouBike",
#   12236             "location": {
#   12237                 "latitude": 24.9936281,
#   12238                 "longitude": 121.3009798,
#   12239                 "city": "桃園市 Taoyuan City",
#   12240                 "country": "TW"
#   12241             },
#   12242             "href": "/v2/networks/youbike-taoyuan",
#   12243             "company": [
#   12244                 "YouBike Co., Ltd."
#   12245             ],
#   12246             "system": "YouBike"
#   12247         },
#   12248         {
#   12249             "id": "yoy-san-luis-potosi",
#   12250             "name": "YOY - San Luis Potosi",
#   12251             "location": {
#   12252                 "latitude": 22.438,
#   12253                 "longitude": -100.514,
#   12254                 "city": "San Luis Potosi",
#   12255                 "country": "MX"
#   12256             },
#   12257             "href": "/v2/networks/yoy-san-luis-potosi",
#   12258             "company": [
#   12259                 "Nextbike GmbH"
#   12260             ]
#   12261         },
#   12262         {
#   12263             "id": "yoy-san-luis-potosi-cancun",
#   12264             "name": "YOY - San Luis Potosi",
#   12265             "location": {
#   12266                 "latitude": 21.1675,
#   12267                 "longitude": -86.8498,
#   12268                 "city": "Cancún",
#   12269                 "country": "MX"
#   12270             },
#   12271             "href": "/v2/networks/yoy-san-luis-potosi-cancun",
#   12272             "company": [
#   12273                 "Nextbike GmbH"
#   12274             ]
#   12275         },
#   12276         {
#   12277             "id": "yverdon-les-bains",
#   12278             "name": "Donkey Republic Yverdon-les-Bains",
#   12279             "location": {
#   12280                 "latitude": 46.7788,
#   12281                 "longitude": 6.6414,
#   12282                 "city": "Yverdon-les-Bains",
#   12283                 "country": "CH"
#   12284             },
#   12285             "href": "/v2/networks/yverdon-les-bains",
#   12286             "company": [
#   12287                 "Donkey Republic"
#   12288             ],
#   12289             "gbfs_href": "https://stables.donkey.bike/api/public/gbfs/2/donkey_yverdon-les-bains/gbfs.json"
#   12290         },
#   12291         {
#   12292             "id": "zebullo",
#   12293             "name": "ZébullO",
#   12294             "location": {
#   12295                 "latitude": 49.2628,
#   12296                 "longitude": 4.0347,
#   12297                 "city": "Reims",
#   12298                 "country": "FR"
#   12299             },
#   12300             "href": "/v2/networks/zebullo",
#   12301             "company": [
#   12302                 "Ecovelo"
#   12303             ],
#   12304             "system": "Ecovelo",
#   12305             "ebikes": true,
#   12306             "gbfs_href": "https://api.gbfs.ecovelo.mobi/zebullo/gbfs.json"
#   12307         },
#   12308         {
#   12309             "id": "zena-by-bike",
#   12310             "name": "Zena By Bike",
#   12311             "location": {
#   12312                 "latitude": 44.40430089372731,
#   12313                 "longitude": 8.92908986230462,
#   12314                 "city": "Genova",
#   12315                 "country": "IT"
#   12316             },
#   12317             "href": "/v2/networks/zena-by-bike",
#   12318             "company": [
#   12319                 "Bicincitta Italia S.r.l."
#   12320             ],
#   12321             "system": "Weelo"
#   12322         },
#   12323         {
#   12324             "id": "zoov-paris-sud",
#   12325             "name": "Zoov",
#   12326             "location": {
#   12327                 "latitude": 48.7429,
#   12328                 "longitude": 2.238,
#   12329                 "city": "Paris Sud",
#   12330                 "country": "FR"
#   12331             },
#   12332             "href": "/v2/networks/zoov-paris-sud",
#   12333             "company": [
#   12334                 "Fifteen SAS"
#   12335             ],
#   12336             "source": "https://www.data.gouv.fr/fr/datasets/r/4646ba01-4fe0-4cd8-91d3-09e204bbaf86",
#   12337             "license": {
#   12338                 "name": "Open Data Commons Open Database License (ODbL)",
#   12339                 "url": "http://opendatacommons.org/licenses/odbl/summary/"
#   12340             },
#   12341             "gbfs_href": "https://gateway.prod.zoov.io/gbfs/2.2/saclay/en/gbfs.json?key=NGFlMjU3MDUtNDk5My00MTM4LTk1ZjctNmNlNDM1MWQ0NjE1"
#   12342         }
#   12343     ]
#   12344 }
#
# NameError: name 'true' is not defined

# %%
import json

# Open a file in write mode and save the JSON data
with open("sample_networks.json", "w") as json_file:
    json.dump(all_networks, json_file, indent=2)  # indent is optional, it formats the output to be more readable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 # Open a file in write mode and save the JSON data
#       4 with open("sample_networks.json", "w") as json_file:
# ----> 5     json.dump(all_networks, json_file, indent=2)  # indent is optional, it formats the output to be more readable
#
# NameError: name 'all_networks' is not defined

# %%
import json

# Load the saved JSON data
with open("sample_networks.json", "r") as json_file:
    all_networks = json.load(json_file)

# %%
import aiohttp
import asyncio
import json


async def fetch(url: str):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            if response.status == 200:
                data = await response.json()
                return data


async def fetch_all_stations(url: str, api_key: str, all_locations: dict) -> None:  

  
api_key = "d9e86164ec8843ae9a2200103251704"

city_list =  []
                    
tasks = []

for city in city_list:
    url = f"https://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
    tasks.append(fetch(url))


responses = await asyncio.gather(*tasks)


all_stations = []
                
if len(responses) == len(all_locations): 
    for response in responses:
        if response:
            location_data = response.get("location", {})
            current = response.get("current", {})

            if location_data and current:
                streaming_data = {
                    "city": location_data.get("name"),
                    "lat": location_data.get("lat"),
                    "lon": location_data.get("lon"),
                    "timezone": location_data.get("tz_id"),
                    "country": location_data.get("country"),
                    "localtime": location_data.get("localtime"),
                    "city": location_data.get("name"),
                    "last_updated": current.get("last_updated"),
                    "condition": current.get("condition", {}).get("text"),
                    "temp_c": current.get("temp_c"),
                    "wind_mph": current.get("wind_mph"),
                    "wind_degree": current.get("wind_degree"),
                    "wind_dir": current.get("wind_dir"),
                    "humidity": current.get("humidity"),
                    "cloud": current.get("cloud"),
                    "feelslike_c": current.get("feelslike_c"),
                    "heat_index": current.get("heatindex_c"),
                }

                all_stations.append(streaming_data)

    # return all_stations
            

# all_weather = await fetch_all_stations()
# Out:
# https://api.weatherapi.com/v1/current.json?key=d9e86164ec8843ae9a2200103251704&q=48.433333,-71.083333
# https://api.weatherapi.com/v1/current.json?key=d9e86164ec8843ae9a2200103251704&q=40.7128,-74.0060
# https://api.weatherapi.com/v1/current.json?key=d9e86164ec8843ae9a2200103251704&q=40.736,-74.173

# %%
all_locations =  [
                {"location_id": '8e3dc927-4297-4ba8-96b3-4cf99eff8762', "latitude": 51.5074, "longitude": -0.1278},  
                {"location_id": '19d95950-6b2a-445c-b3c6-0847a97b4276', "latitude": 40.7128, "longitude": -74.0060},
                {"location_id": 'ad1c044c-3d84-4b1c-aa2d-2a3aa34e2143',"latitude": 35.6895, "longitude": 139.6917}]
                    




for location in all_locations:
    url = f"https://api.weatherapi.com/v1/current.json/?key={api_key}&q={location['latitude']},{location['longitude']}"
    print(url)
# Out:
# https://api.weatherapi.com/v1/current.json/?key=350f4d977ad24531a8565131251704&q=51.5074,-0.1278
# https://api.weatherapi.com/v1/current.json/?key=350f4d977ad24531a8565131251704&q=40.7128,-74.006
# https://api.weatherapi.com/v1/current.json/?key=350f4d977ad24531a8565131251704&q=35.6895,139.6917

# %%
import uuid

def generate_uuid():
    return str(uuid.uuid4()) # Generates a random UUID  

generate_uuid()
# Out:
# 'ad1c044c-3d84-4b1c-aa2d-2a3aa34e2143'

# %%
# add to transformation script
import uuid
import pandas as pd
import os

df = df.withColumn("location_id", str(uuid.uuid4()))

if os.path.exists("reference_data/city_list.csv") == False:
    city_df = df.select("city").distinct()
    spark.write.csv(
    city_df, "reference_data/city_list.csv", header=True, mode="overwrite"
)
# Out:
# '8e3dc927-4297-4ba8-96b3-4cf99eff8762'

# %%
https://api.weatherapi.com/v1/current.json?key=d9e86164ec8843ae9a2200103251704&q=48.433333,-71.083333
https://api.weatherapi.com/v1/current.json?key=d9e86164ec8843ae9a2200103251704&q=40.7128,-74.0060
https://api.weatherapi.com/v1/current.json?key=d9e86164ec8843ae9a2200103251704&q=40.736,-74.173

# %%
import pandas as pd

location_df = pd.read_csv("reference_data/location_reference.csv")
location_dict = location_df.to_dict(orient="records")

# %%
all_locations =  [
                {"location_id": '8e3dc927-4297-4ba8-96b3-4cf99eff8762', "latitude": 51.5074, "longitude": -0.1278},  
                {"location_id": '19d95950-6b2a-445c-b3c6-0847a97b4276', "latitude": 40.7128, "longitude": -74.0060},
                {"location_id": 'ad1c044c-3d84-4b1c-aa2d-2a3aa34e2143',"latitude": 35.6895, "longitude": 139.6917}]



for location in all_locations:
    print(location["location_id"], location["latitude"], location["longitude"])



# urls = [f"baba{lat},{lon}" for lat, lon in all_locations.items()]
# urls
# Out:
# 8e3dc927-4297-4ba8-96b3-4cf99eff8762 51.5074 -0.1278
# 19d95950-6b2a-445c-b3c6-0847a97b4276 40.7128 -74.006
# ad1c044c-3d84-4b1c-aa2d-2a3aa34e2143 35.6895 139.6917

# %%
all_stations
# Out:
# [{'lat': 51.517,
#   'lon': -0.106,
#   'city': 'London',
#   'temp_c': 8.3,
#   'wind_mph': 2.2,
#   'humidity': 76},
#  {'lat': 40.714,
#   'lon': -74.006,
#   'city': 'New York',
#   'temp_c': 6.7,
#   'wind_mph': 11.6,
#   'humidity': 51},
#  {'lat': 35.69,
#   'lon': 139.692,
#   'city': 'Tokyo',
#   'temp_c': 25.3,
#   'wind_mph': 19.5,
#   'humidity': 34}]

# %%
import json
data = {
    "location": {
        "name": "Bagotville",
        "region": "Quebec",
        "country": "Canada",
        "lat": 48.35,
        "lon": -70.883,
        "tz_id": "America/Toronto",
        "localtime_epoch": 1744874327,
        "localtime": "2025-04-17 03:18"
    },
    "current": {
        "last_updated": "2025-04-17 03:15",
        "temp_c": -0.9,
        "is_day": 0,
        "condition": {
            "text": "Clear"
        },
        "wind_mph": 15.2,
        "wind_degree": 281,
        "wind_dir": "WNW",
        "humidity": 81,
        "cloud": 0,
        "feelslike_c": -7.0,
        "heatindex_c": -2.6,
        "heatindex_f": 27.3,
        "uv": 0.0
    }
}


for response in data:
    if response:
        location = response["location"]
        current = response["current"]
        if location and current:
   
            streaming_data = {
                    "lat": location["lat"],
                    "lon":location["lon"],
                }

            print(streaming_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 36
#      34 for response in data:
#      35     if response:
# ---> 36         location = response["location"]
#      37         current = response["current"]
#      38         if location and current:
#
# TypeError: string indices must be integers

# %%
all_locations =  {
    (51.5074, -0.1278): "London",  
    (40.7128, -74.0060): "New York",
    (35.6895, 139.6917): "Tokyo"
}

all_coordinates = [(lat, lon) for lat, lon in all_locations.keys()]
all_coordinates
# Out:
# [(51.5074, -0.1278), (40.7128, -74.006), (35.6895, 139.6917)]

# %%
# Assuming the JSON is stored in a variable called `weather_data`

weather_data = {
    "location": {
        "name": "Bagotville",
        "region": "Quebec",
        "country": "Canada",
        "lat": 48.35,
        "lon": -70.883,
        "tz_id": "America/Toronto",
        "localtime_epoch": 1744874327,
        "localtime": "2025-04-17 03:18"
    },
    "current": {
        "last_updated": "2025-04-17 03:15",
        "temp_c": -0.9,
        "is_day": 0,
        "condition": {
            "text": "Clear"
        },
        "wind_mph": 15.2,
        "wind_degree": 281,
        "wind_dir": "WNW",
        "humidity": 81,
        "cloud": 0,
        "feelslike_c": -7.0,
        "heatindex_c": -2.6,
        "heatindex_f": 27.3,
        "uv": 0.0
    }
}

# Extracting data
location_name = weather_data["location"]["name"]
country = weather_data["location"]["country"]
localtime = weather_data["location"]["localtime"]
temperature = weather_data["current"]["temp_c"]
feels_like = weather_data["current"]["feelslike_c"]
weather_condition = weather_data["current"]["condition"]["text"]
wind_speed = weather_data["current"]["wind_mph"]
humidity = weather_data["current"]["humidity"]

# Optional: Display
print(f"Location: {location_name}, {country}")
print(f"Local Time: {localtime}")
print(f"Temperature: {temperature}°C, Feels Like: {feels_like}°C")
print(f"Condition: {weather_condition}")
print(f"Wind Speed: {wind_speed} mph")
print(f"Humidity: {humidity}%")
# Out:
# Location: Bagotville, Canada
# Local Time: 2025-04-17 03:18
# Temperature: -0.9°C, Feels Like: -7.0°C
# Condition: Clear
# Wind Speed: 15.2 mph
# Humidity: 81%

# %%
#version 2
import aiohttp
import asyncio
import json
import csv
import time



async def fetch(url: str) -> dict:
    """ Fetch data from API asynchronously """

    try:
        async with aiohttp.ClientSession() as session:
            async with session.get(url) as response:
                if response.status == 200:
                    data = await response.text()
                    return data
                logging.info("Data fetched successfully.")
    except aiohttp.ClientError as e:
        logging.error(f"Error fetching data: {e}")
        return None
    

    
async def fetch_all_stations():

    """ Fetch all bike networks asynchronously """


    all_ids = [ 'beryl-brighton',
                'beryl-cornwall',
                'beryl-dorchester-weymouth-portland']
    
    url = "http://api.citybik.es/v2/networks"
    urls = [f"{url}/{network_id}" for network_id in all_ids]

    tasks = []
    for url in urls:
        tasks.append(fetch(url))    
        

    responses = await asyncio.gather(*tasks)

    all_stations = []

    for response in responses:
        if response:
            response = json.loads(response)  # convert text (str) to json to extract the networks

        tasks_stations = response.get("network", {}).get("stations", [])
        

        for stations in tasks_stations:
            streaming_data = ({
                "id": response.get("network", {}).get("id"),
                "station_id": stations["id"],
                "name": stations["name"],
                "latitude": stations["latitude"],
                "longitude": stations["longitude"],
                "last_updated": stations["timestamp"],  # rename timestamp key to last_updated
                "free_bikes": stations["free_bikes"],
                "empty_slots": stations["empty_slots"],
                "uid": stations["extra"].get("uid", None),
                "renting": stations["extra"].get("renting", 0),
                "returning": stations["extra"].get("returning", 0),
                "address": stations["extra"].get("address", None),
                "has_ebikes": stations["extra"].get("has_ebikes", 0),
                "ebikes": stations["extra"].get("ebikes", 0),
                "normal_bikes": stations["extra"].get("normal_bikes", 0),
                "number": stations["extra"].get("number", 0),
                "slots": stations["extra"].get("slots", 0),
                "current_timestamp": time.time()             #insert runtime timestamp
            })
            
            all_stations.append(streaming_data)
    return all_stations

stations = await fetch_all_stations()

# %%
import json

# Open a file in write mode and save the JSON data
with open("sample_stations.json", "w") as json_file:
    json.dump(stations, json_file, indent=2)  # indent is optional, it formats the output to be more readable
